# %% [markdown]
# Project: # Patil_ADEarlyDetection
#
# # **Phase 1:**
# ## CNN with TL = VGG16

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/My Drive/AD_proj"
# Out:
# Mounted at /content/drive
# ad_proj_try1.ipynb  ad_proj_try2.ipynb	Alzheimer_s_Dataset  my_best_models

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
#from keras.applications.densenet import DenseNet169, DenseNet121, DenseNet201 #https://keras.io/api/applications/densenet/
from keras.applications import VGG16, VGG19 #https://keras.io/api/applications/vgg/
from keras.applications.vgg16 import preprocess_input
#from keras.applications.resnet50 import preprocess_input
from keras.callbacks import EarlyStopping, ModelCheckpoint

import numpy as np
#import IPython

from matplotlib import pyplot as plt

#import sys
#sys.path.append('/content/drive/My Drive/AD_proj')

#my helper functions
#import ad_helper_functions
#ad_helper_functions.ad_proj_help()

#
# Define constants
#
NUM_EPOCH =  100
NUM_PATIENCE =  20

NUM_BATCH_SIZE = 128
NUM_IMAGE_SIZE =224
NUM_VAL_SPLIT = 0.2
NUM_IMG_RESCALE = 1/255
NUM_LEARNING_RATE = 0.001 #Choose form [1e-2, 1e-3, 1e-4]

# To prevent overfitting
NUM_DROPOUT_RATE=0.5
NUM_FILL_GRAY = 125.0

# Base Model choice
NUM_CHOICE_DENSENET169 = 1

# %%
#
# DATA AUGMENTATION:  
# Augment the train data to make sure each EPOCH does NOT train on same image
# i.e. train data will be augmented on every epoch
#
train = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=NUM_VAL_SPLIT,
                           rotation_range=40,
                           zoom_range=NUM_VAL_SPLIT,
#                           width_shift_range=NUM_VAL_SPLIT, 
#                           height_shift_range=NUM_VAL_SPLIT,
#                           fill_mode='constant', 
#                           cval=NUM_FILL_GRAY,                            
                           horizontal_flip=True, 
                           vertical_flip=True, 
                           rescale=NUM_IMG_RESCALE)

val = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)
test = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)

train_dataset = train.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='training')

val_dataset = val.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='validation')

test_dataset = test.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/test', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical')
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
# All Helper functions
#--------------------------------------------------------------------
# Function Name: f_ad_model_builder
# Description: Build Convolutional Neural Network (CNN) Deep learning model
#              for early diagnosis of Alzheimer's disease
#--------------------------------------------------------------------
def f_ad_model_builder():

  #if base_model_choice == NUM_CHOICE_DENSENET169:

  #Choose CNN based model of DenseNet169
  #model_densenet169 = DenseNet169(input_shape=(NUM_IMAGE_SIZE,NUM_IMAGE_SIZE,3), include_top=False, weights="imagenet")
  # Set include tope=False, so fully-connected output layers of the model used to make predictions is not loaded, allowing a new output layer to be added and trained
  model_vgg16 = VGG16(input_shape=(NUM_IMAGE_SIZE,NUM_IMAGE_SIZE,3), include_top=False, weights="imagenet")

  # freeze layers
  for layer in model_vgg16.layers :
    layer.trainable = False

  model = Sequential() # seq model is a linear stacks of layers
  model.add(model_vgg16)
 # else:
#      print("TBD?????? ")

  # Dropout to prevent overfitting
  # Train model on some layer outputs are randomly ignored or “dropped out.” 
  # This has the effect of making the layer look-like and be treated-like a layer with a different 
  # number of nodes and connectivity to the prior layer.
  model.add(Dropout(rate=0.5))

  # Flatten: Rectangular or cubic shapes can't be direct inputs & connected layer. 
  # We flatten the output of the convolutional layers to create a 1-dimentional array (single long feature vector)
  model.add(Flatten())

  # Dense Layer 1 
  model.add(BatchNormalization()) # Batch Normalization: to imporve the training speed
  model.add(Dense(units=2048, kernel_initializer='he_uniform'))

  # Dense Layer 2
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(rate=0.5))
  model.add(Dense(units=1024, kernel_initializer='he_uniform'))

  # Final Dense Layer
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(rate=0.5))
  model.add(Dense(units=4, activation='softmax'))

  # printout whole model: Hidden layer + Dense Layer
  model.summary()
 
  #
  # COMPILE: Choose learning rate from 0.01, 0.001, or 0.0001 i.e. [1e-2, 1e-3, 1e-4]
  # Optimizer: optimizers shape and mold your model into its most accurate possible form by manipulating weights
  model.compile(optimizer = keras.optimizers.Adam(learning_rate = NUM_LEARNING_RATE),
                loss = 'categorical_crossentropy', 
                metrics = [tf.keras.metrics.AUC(name = 'auc')])
  
  return model

#--------------------------------------------------------------------
# Function Name: f_all_ad_plot_model
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_all_plot_model(hist):

    plt.plot(hist.history["acc"])
    plt.plot(hist.history['val_acc'])
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title("AD Early Detection Model Accuracy")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.legend(["Training Accuracy","Validation Accuracy","Training loss","Validation Loss"])

    # Show the plot
    plt.show()

#--------------------------------------------------------------------
# Function Name: f_ad_plot_auc_loss
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_plot_auc_loss(f_model):

  # create subplots
  fig, axs = plt.subplots(1,2,figsize=(15,10))

  ticks = np.arange(1,len(f_model.history['loss'])+1)
  history_auc_length = len(f_model.history['auc'])+1
  history_val_auc_length = len(f_model.history['val_auc'])+1
  history_loss_length = len(f_model.history['loss'])+1
  history_val_loss_length = len(f_model.history['val_loss'])+1

  # Summarize history for auc
  axs[0].plot(range(1,history_auc_length), f_model.history['auc'])
  axs[0].plot(range(1,history_val_auc_length), f_model.history['val_auc'])
  axs[0].set_title('Model AUC')
  axs[0].set_ylabel('AUC')
  axs[0].set_xlabel('Epoch')
  axs[0].set_xticks(ticks,len(f_model.history['auc'])/10)
  axs[0].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

  # Summarize history for loss
  axs[1].plot(range(1, history_loss_length), f_model.history['loss'])
  axs[1].plot(range(1,history_val_loss_length), f_model.history['val_loss'])
  axs[1].set_title('Model Loss')
  axs[1].set_ylabel('Loss')
  axs[1].set_xlabel('Epoch')
  axs[1].set_xticks(ticks,len(f_model.history['loss'])/10)
  axs[1].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

#--------------------------------------------------------------------
# Function Name: 
# Description: 
#              
#--------------------------------------------------------------------
# ??? how to calculate fpr/tpr
def f_ad_plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, 'b',color='orange', label='AUC = %0.2f' % roc_auc)
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate (FPR) ')
    plt.ylabel('True Positive Rate (TPR) ')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc = 'lower right')
    plt.show()
#--------------------------------------------------------------------
# Function Name: f_ad_plot_model
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_plot_acc_loss(f_model):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,10))
    ticks = np.arange(1,len(f_model.history['loss'])+1)
    history_acc_length = len(f_model.history['accuracy'])+1
    history_val_accuracy_length = len(f_model.history['val_accuracy'])+1
    history_loss_length = len(f_model.history['loss'])+1
    history_val_loss_length = len(f_model.history['val_loss'])+1

    # Summarize history for accuracy
    axs[0].plot(range(1,history_acc_length), f_model.history['accuracy'])
    axs[0].plot(range(1,history_val_accuracy_length), f_model.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(ticks,len(f_model.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Summarize history for loss
    axs[1].plot(range(1, history_loss_length), f_model.history['loss'])
    axs[1].plot(range(1,history_val_loss_length), f_model.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(ticks,len(f_model.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()

# %%
# build model with Choice of base Model
model = f_ad_model_builder()

# Define callbacks
checkpoint = ModelCheckpoint("/content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5", monitor='val_auc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_auc', min_delta=0, patience=NUM_PATIENCE, verbose=1, mode='max') 

model_history=model.fit(train_dataset,
                        validation_data=val_dataset,
                        epochs = NUM_EPOCH,
                        callbacks = [checkpoint, early],
                        verbose = 1)

print('--------------------------------------------\n')
print('Results [with VGG16] :')
f_ad_plot_auc_loss(model_history)

#!ls -al '/content/drive/My Drive/AD_proj/my_best_models'
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25088)             100352
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              51382272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_2 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 68,311,876
# Trainable params: 53,540,868
# Non-trainable params: 14,771,008
# _________________________________________________________________
# Epoch 1/100
# 33/33 [==============================] - 54s 2s/step - loss: 1.6046 - auc: 0.7083 - val_loss: 1.0991 - val_auc: 0.7875
#
# Epoch 00001: val_auc improved from -inf to 0.78753, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 2/100
# 33/33 [==============================] - 53s 2s/step - loss: 1.1940 - auc: 0.8149 - val_loss: 1.0360 - val_auc: 0.8037
#
# Epoch 00002: val_auc improved from 0.78753 to 0.80374, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 3/100
# 33/33 [==============================] - 53s 2s/step - loss: 1.1058 - auc: 0.8196 - val_loss: 1.1129 - val_auc: 0.7715
#
# Epoch 00003: val_auc did not improve from 0.80374
# Epoch 4/100
# 33/33 [==============================] - 52s 2s/step - loss: 1.0372 - auc: 0.8352 - val_loss: 1.0951 - val_auc: 0.7987
#
# Epoch 00004: val_auc did not improve from 0.80374
# Epoch 5/100
# 33/33 [==============================] - 51s 2s/step - loss: 1.0783 - auc: 0.8280 - val_loss: 1.0484 - val_auc: 0.7829
#
# Epoch 00005: val_auc did not improve from 0.80374
# Epoch 6/100
# 33/33 [==============================] - 52s 2s/step - loss: 0.9500 - auc: 0.8452 - val_loss: 0.9760 - val_auc: 0.8179
#
# Epoch 00006: val_auc improved from 0.80374 to 0.81793, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 7/100
# 33/33 [==============================] - 53s 2s/step - loss: 0.9201 - auc: 0.8558 - val_loss: 1.0594 - val_auc: 0.7871
#
# Epoch 00007: val_auc did not improve from 0.81793
# Epoch 8/100
# 33/33 [==============================] - 51s 2s/step - loss: 0.8909 - auc: 0.8621 - val_loss: 1.0413 - val_auc: 0.8104
#
# Epoch 00008: val_auc did not improve from 0.81793
# Epoch 9/100
# 33/33 [==============================] - 52s 2s/step - loss: 0.8738 - auc: 0.8676 - val_loss: 1.0902 - val_auc: 0.8085
#
# Epoch 00009: val_auc did not improve from 0.81793
# Epoch 10/100
# 33/33 [==============================] - 52s 2s/step - loss: 0.8554 - auc: 0.8701 - val_loss: 1.0900 - val_auc: 0.7817
#
# Epoch 00010: val_auc did not improve from 0.81793
# Epoch 11/100
# 33/33 [==============================] - 52s 2s/step - loss: 0.8443 - auc: 0.8739 - val_loss: 1.0289 - val_auc: 0.8021
#
# Epoch 00011: val_auc did not improve from 0.81793
# Epoch 12/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.8270 - auc: 0.8769 - val_loss: 0.9916 - val_auc: 0.8101
#
# Epoch 00012: val_auc did not improve from 0.81793
# Epoch 13/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.8195 - auc: 0.8783 - val_loss: 1.0585 - val_auc: 0.8044
#
# Epoch 00013: val_auc did not improve from 0.81793
# Epoch 14/100
# 33/33 [==============================] - 53s 2s/step - loss: 0.7828 - auc: 0.8874 - val_loss: 0.9856 - val_auc: 0.8195
#
# Epoch 00014: val_auc improved from 0.81793 to 0.81953, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 15/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7812 - auc: 0.8864 - val_loss: 1.0153 - val_auc: 0.8060
#
# Epoch 00015: val_auc did not improve from 0.81953
# Epoch 16/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.7509 - auc: 0.8985 - val_loss: 1.1304 - val_auc: 0.8138
#
# Epoch 00016: val_auc did not improve from 0.81953
# Epoch 17/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.7457 - auc: 0.8978 - val_loss: 1.0770 - val_auc: 0.8122
#
# Epoch 00017: val_auc did not improve from 0.81953
# Epoch 18/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.8017 - auc: 0.8841 - val_loss: 0.9999 - val_auc: 0.8290
#
# Epoch 00018: val_auc improved from 0.81953 to 0.82897, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 19/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7573 - auc: 0.8926 - val_loss: 1.1157 - val_auc: 0.8254
#
# Epoch 00019: val_auc did not improve from 0.82897
# Epoch 20/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7336 - auc: 0.9012 - val_loss: 1.0879 - val_auc: 0.8185
#
# Epoch 00020: val_auc did not improve from 0.82897
# Epoch 21/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7002 - auc: 0.9088 - val_loss: 1.0384 - val_auc: 0.8275
#
# Epoch 00021: val_auc did not improve from 0.82897
# Epoch 22/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7501 - auc: 0.8969 - val_loss: 1.0179 - val_auc: 0.8325
#
# Epoch 00022: val_auc improved from 0.82897 to 0.83248, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 23/100
# 33/33 [==============================] - 58s 2s/step - loss: 0.7276 - auc: 0.9012 - val_loss: 1.0585 - val_auc: 0.8361
#
# Epoch 00023: val_auc improved from 0.83248 to 0.83606, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 24/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.7070 - auc: 0.9090 - val_loss: 1.0162 - val_auc: 0.8359
#
# Epoch 00024: val_auc did not improve from 0.83606
# Epoch 25/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7322 - auc: 0.9010 - val_loss: 1.1319 - val_auc: 0.8015
#
# Epoch 00025: val_auc did not improve from 0.83606
# Epoch 26/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7445 - auc: 0.8967 - val_loss: 1.0386 - val_auc: 0.8269
#
# Epoch 00026: val_auc did not improve from 0.83606
# Epoch 27/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.7231 - auc: 0.9028 - val_loss: 1.0226 - val_auc: 0.8273
#
# Epoch 00027: val_auc did not improve from 0.83606
# Epoch 28/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7129 - auc: 0.9075 - val_loss: 1.1128 - val_auc: 0.8173
#
# Epoch 00028: val_auc did not improve from 0.83606
# Epoch 29/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.7006 - auc: 0.9074 - val_loss: 0.9953 - val_auc: 0.8360
#
# Epoch 00029: val_auc did not improve from 0.83606
# Epoch 30/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.7195 - auc: 0.9043 - val_loss: 1.0223 - val_auc: 0.8154
#
# Epoch 00030: val_auc did not improve from 0.83606
# Epoch 31/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.7023 - auc: 0.9078 - val_loss: 1.0771 - val_auc: 0.8187
#
# Epoch 00031: val_auc did not improve from 0.83606
# Epoch 32/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.6955 - auc: 0.9107 - val_loss: 0.9906 - val_auc: 0.8403
#
# Epoch 00032: val_auc improved from 0.83606 to 0.84031, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 33/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6862 - auc: 0.9134 - val_loss: 1.0859 - val_auc: 0.8344
#
# Epoch 00033: val_auc did not improve from 0.84031
# Epoch 34/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6750 - auc: 0.9154 - val_loss: 1.0695 - val_auc: 0.8330
#
# Epoch 00034: val_auc did not improve from 0.84031
# Epoch 35/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.6747 - auc: 0.9164 - val_loss: 1.0021 - val_auc: 0.8419
#
# Epoch 00035: val_auc improved from 0.84031 to 0.84186, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 36/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6840 - auc: 0.9145 - val_loss: 0.9781 - val_auc: 0.8501
#
# Epoch 00036: val_auc improved from 0.84186 to 0.85007, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 37/100
# 33/33 [==============================] - 57s 2s/step - loss: 0.6755 - auc: 0.9168 - val_loss: 1.0832 - val_auc: 0.8396
#
# Epoch 00037: val_auc did not improve from 0.85007
# Epoch 38/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6760 - auc: 0.9163 - val_loss: 1.0893 - val_auc: 0.8297
#
# Epoch 00038: val_auc did not improve from 0.85007
# Epoch 39/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6758 - auc: 0.9160 - val_loss: 1.1903 - val_auc: 0.8329
#
# Epoch 00039: val_auc did not improve from 0.85007
# Epoch 40/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6535 - auc: 0.9204 - val_loss: 1.0320 - val_auc: 0.8374
#
# Epoch 00040: val_auc did not improve from 0.85007
# Epoch 41/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6676 - auc: 0.9170 - val_loss: 1.0351 - val_auc: 0.8393
#
# Epoch 00041: val_auc did not improve from 0.85007
# Epoch 42/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6679 - auc: 0.9168 - val_loss: 1.0948 - val_auc: 0.8399
#
# Epoch 00042: val_auc did not improve from 0.85007
# Epoch 43/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6391 - auc: 0.9241 - val_loss: 1.0976 - val_auc: 0.8259
#
# Epoch 00043: val_auc did not improve from 0.85007
# Epoch 44/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6354 - auc: 0.9261 - val_loss: 1.0320 - val_auc: 0.8447
#
# Epoch 00044: val_auc did not improve from 0.85007
# Epoch 45/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6416 - auc: 0.9242 - val_loss: 1.0242 - val_auc: 0.8427
#
# Epoch 00045: val_auc did not improve from 0.85007
# Epoch 46/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6112 - auc: 0.9303 - val_loss: 1.0010 - val_auc: 0.8394
#
# Epoch 00046: val_auc did not improve from 0.85007
# Epoch 47/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6708 - auc: 0.9167 - val_loss: 1.0217 - val_auc: 0.8426
#
# Epoch 00047: val_auc did not improve from 0.85007
# Epoch 48/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6382 - auc: 0.9252 - val_loss: 0.9777 - val_auc: 0.8530
#
# Epoch 00048: val_auc improved from 0.85007 to 0.85298, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 49/100
# 33/33 [==============================] - 58s 2s/step - loss: 0.6246 - auc: 0.9278 - val_loss: 1.0137 - val_auc: 0.8480
#
# Epoch 00049: val_auc did not improve from 0.85298
# Epoch 50/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6139 - auc: 0.9295 - val_loss: 1.0213 - val_auc: 0.8519
#
# Epoch 00050: val_auc did not improve from 0.85298
# Epoch 51/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6414 - auc: 0.9251 - val_loss: 1.0599 - val_auc: 0.8331
#
# Epoch 00051: val_auc did not improve from 0.85298
# Epoch 52/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6524 - auc: 0.9223 - val_loss: 1.0143 - val_auc: 0.8528
#
# Epoch 00052: val_auc did not improve from 0.85298
# Epoch 53/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.6235 - auc: 0.9284 - val_loss: 0.9819 - val_auc: 0.8506
#
# Epoch 00053: val_auc did not improve from 0.85298
# Epoch 54/100
# 33/33 [==============================] - 53s 2s/step - loss: 0.6145 - auc: 0.9299 - val_loss: 0.9975 - val_auc: 0.8487
#
# Epoch 00054: val_auc did not improve from 0.85298
# Epoch 55/100
# 33/33 [==============================] - 53s 2s/step - loss: 0.6129 - auc: 0.9310 - val_loss: 0.9877 - val_auc: 0.8558
#
# Epoch 00055: val_auc improved from 0.85298 to 0.85584, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 56/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.6194 - auc: 0.9291 - val_loss: 1.0406 - val_auc: 0.8527
#
# Epoch 00056: val_auc did not improve from 0.85584
# Epoch 57/100
# 33/33 [==============================] - 52s 2s/step - loss: 0.6089 - auc: 0.9321 - val_loss: 1.0633 - val_auc: 0.8541
#
# Epoch 00057: val_auc did not improve from 0.85584
# Epoch 58/100
# 33/33 [==============================] - 53s 2s/step - loss: 0.6145 - auc: 0.9316 - val_loss: 1.0546 - val_auc: 0.8336
#
# Epoch 00058: val_auc did not improve from 0.85584
# Epoch 59/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.6583 - auc: 0.9199 - val_loss: 0.9870 - val_auc: 0.8604
#
# Epoch 00059: val_auc improved from 0.85584 to 0.86045, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 60/100
# 33/33 [==============================] - 57s 2s/step - loss: 0.6334 - auc: 0.9266 - val_loss: 1.0238 - val_auc: 0.8587
#
# Epoch 00060: val_auc did not improve from 0.86045
# Epoch 61/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.5947 - auc: 0.9351 - val_loss: 1.1031 - val_auc: 0.8276
#
# Epoch 00061: val_auc did not improve from 0.86045
# Epoch 62/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5996 - auc: 0.9340 - val_loss: 1.0466 - val_auc: 0.8455
#
# Epoch 00062: val_auc did not improve from 0.86045
# Epoch 63/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5987 - auc: 0.9333 - val_loss: 1.0632 - val_auc: 0.8555
#
# Epoch 00063: val_auc did not improve from 0.86045
# Epoch 64/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.6176 - auc: 0.9303 - val_loss: 1.0105 - val_auc: 0.8636
#
# Epoch 00064: val_auc improved from 0.86045 to 0.86359, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 65/100
# 33/33 [==============================] - 57s 2s/step - loss: 0.6031 - auc: 0.9326 - val_loss: 0.9622 - val_auc: 0.8618
#
# Epoch 00065: val_auc did not improve from 0.86359
# Epoch 66/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5672 - auc: 0.9398 - val_loss: 0.9073 - val_auc: 0.8712
#
# Epoch 00066: val_auc improved from 0.86359 to 0.87121, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 67/100
# 33/33 [==============================] - 57s 2s/step - loss: 0.6010 - auc: 0.9335 - val_loss: 0.9340 - val_auc: 0.8721
#
# Epoch 00067: val_auc improved from 0.87121 to 0.87212, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 68/100
# 33/33 [==============================] - 58s 2s/step - loss: 0.5866 - auc: 0.9371 - val_loss: 1.0341 - val_auc: 0.8576
#
# Epoch 00068: val_auc did not improve from 0.87212
# Epoch 69/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6038 - auc: 0.9338 - val_loss: 1.0553 - val_auc: 0.8554
#
# Epoch 00069: val_auc did not improve from 0.87212
# Epoch 70/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5860 - auc: 0.9396 - val_loss: 0.9497 - val_auc: 0.8730
#
# Epoch 00070: val_auc improved from 0.87212 to 0.87300, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 71/100
# 33/33 [==============================] - 58s 2s/step - loss: 0.5562 - auc: 0.9422 - val_loss: 0.9578 - val_auc: 0.8701
#
# Epoch 00071: val_auc did not improve from 0.87300
# Epoch 72/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5806 - auc: 0.9378 - val_loss: 0.9525 - val_auc: 0.8689
#
# Epoch 00072: val_auc did not improve from 0.87300
# Epoch 73/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.6047 - auc: 0.9333 - val_loss: 0.9684 - val_auc: 0.8660
#
# Epoch 00073: val_auc did not improve from 0.87300
# Epoch 74/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5701 - auc: 0.9386 - val_loss: 0.9860 - val_auc: 0.8712
#
# Epoch 00074: val_auc did not improve from 0.87300
# Epoch 75/100
# 33/33 [==============================] - 54s 2s/step - loss: 0.5448 - auc: 0.9453 - val_loss: 0.9045 - val_auc: 0.8752
#
# Epoch 00075: val_auc improved from 0.87300 to 0.87519, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 76/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5399 - auc: 0.9465 - val_loss: 0.9517 - val_auc: 0.8670
#
# Epoch 00076: val_auc did not improve from 0.87519
# Epoch 77/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5700 - auc: 0.9402 - val_loss: 0.9948 - val_auc: 0.8652
#
# Epoch 00077: val_auc did not improve from 0.87519
# Epoch 78/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5655 - auc: 0.9410 - val_loss: 0.9207 - val_auc: 0.8702
#
# Epoch 00078: val_auc did not improve from 0.87519
# Epoch 79/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5380 - auc: 0.9462 - val_loss: 0.9763 - val_auc: 0.8663
#
# Epoch 00079: val_auc did not improve from 0.87519
# Epoch 80/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5431 - auc: 0.9449 - val_loss: 0.9725 - val_auc: 0.8707
#
# Epoch 00080: val_auc did not improve from 0.87519
# Epoch 81/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5534 - auc: 0.9442 - val_loss: 0.9214 - val_auc: 0.8750
#
# Epoch 00081: val_auc did not improve from 0.87519
# Epoch 82/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5359 - auc: 0.9463 - val_loss: 0.9907 - val_auc: 0.8598
#
# Epoch 00082: val_auc did not improve from 0.87519
# Epoch 83/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5589 - auc: 0.9426 - val_loss: 0.9611 - val_auc: 0.8643
#
# Epoch 00083: val_auc did not improve from 0.87519
# Epoch 84/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5303 - auc: 0.9480 - val_loss: 0.9119 - val_auc: 0.8765
#
# Epoch 00084: val_auc improved from 0.87519 to 0.87653, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 85/100
# 33/33 [==============================] - 57s 2s/step - loss: 0.5630 - auc: 0.9405 - val_loss: 0.9067 - val_auc: 0.8799
#
# Epoch 00085: val_auc improved from 0.87653 to 0.87988, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 86/100
# 33/33 [==============================] - 58s 2s/step - loss: 0.5311 - auc: 0.9477 - val_loss: 0.8994 - val_auc: 0.8799
#
# Epoch 00086: val_auc improved from 0.87988 to 0.87991, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg16_rev0.hdf5
# Epoch 87/100
# 33/33 [==============================] - 57s 2s/step - loss: 0.5621 - auc: 0.9414 - val_loss: 0.9132 - val_auc: 0.8736
#
# Epoch 00087: val_auc did not improve from 0.87991
# Epoch 88/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5324 - auc: 0.9473 - val_loss: 0.9673 - val_auc: 0.8691
#
# Epoch 00088: val_auc did not improve from 0.87991
# Epoch 89/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5435 - auc: 0.9454 - val_loss: 0.9775 - val_auc: 0.8646
#
# Epoch 00089: val_auc did not improve from 0.87991
# Epoch 90/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5169 - auc: 0.9514 - val_loss: 0.9751 - val_auc: 0.8683
#
# Epoch 00090: val_auc did not improve from 0.87991
# Epoch 91/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5382 - auc: 0.9465 - val_loss: 0.9867 - val_auc: 0.8687
#
# Epoch 00091: val_auc did not improve from 0.87991
# Epoch 92/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5267 - auc: 0.9488 - val_loss: 1.0081 - val_auc: 0.8682
#
# Epoch 00092: val_auc did not improve from 0.87991
# Epoch 93/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5244 - auc: 0.9493 - val_loss: 1.0446 - val_auc: 0.8615
#
# Epoch 00093: val_auc did not improve from 0.87991
# Epoch 94/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5373 - auc: 0.9467 - val_loss: 0.9460 - val_auc: 0.8722
#
# Epoch 00094: val_auc did not improve from 0.87991
# Epoch 95/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5322 - auc: 0.9473 - val_loss: 1.0171 - val_auc: 0.8663
#
# Epoch 00095: val_auc did not improve from 0.87991
# Epoch 96/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5418 - auc: 0.9463 - val_loss: 1.0387 - val_auc: 0.8666
#
# Epoch 00096: val_auc did not improve from 0.87991
# Epoch 97/100
# 33/33 [==============================] - 56s 2s/step - loss: 0.5152 - auc: 0.9513 - val_loss: 1.0106 - val_auc: 0.8605
#
# Epoch 00097: val_auc did not improve from 0.87991
# Epoch 98/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5519 - auc: 0.9449 - val_loss: 1.1413 - val_auc: 0.8513
#
# Epoch 00098: val_auc did not improve from 0.87991
# Epoch 99/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5224 - auc: 0.9491 - val_loss: 0.9626 - val_auc: 0.8762
#
# Epoch 00099: val_auc did not improve from 0.87991
# Epoch 100/100
# 33/33 [==============================] - 55s 2s/step - loss: 0.5219 - auc: 0.9503 - val_loss: 1.0162 - val_auc: 0.8707
#
# Epoch 00100: val_auc did not improve from 0.87991
# --------------------------------------------
#
# Results [with VGG16] :
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:107: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:116: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
