# %% [markdown]
# Project: # Patil_ADEarlyDetection
#
# # **Phase 1:**
# ## CNN with TL = VGG19

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/My Drive/AD_proj"
# Out:
# Mounted at /content/drive
# ad_proj_try1.ipynb  ad_proj_try2.ipynb	Alzheimer_s_Dataset  my_best_models

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
#from keras.applications.densenet import DenseNet169, DenseNet121, DenseNet201 #https://keras.io/api/applications/densenet/
from keras.applications import VGG16, VGG19 #https://keras.io/api/applications/vgg/
from keras.applications.vgg19 import preprocess_input
#from keras.applications.resnet50 import preprocess_input
from keras.callbacks import EarlyStopping, ModelCheckpoint

import numpy as np
#import IPython

from matplotlib import pyplot as plt

import sys
sys.path.append('/content/drive/My Drive/AD_proj')


#
# Define constants
#
NUM_EPOCH =  100
NUM_PATIENCE =  20

NUM_BATCH_SIZE = 128
NUM_IMAGE_SIZE =224
NUM_VAL_SPLIT = 0.2
NUM_IMG_RESCALE = 1/255
NUM_LEARNING_RATE = 0.001 #Choose form [1e-2, 1e-3, 1e-4]

# To prevent overfitting
NUM_DROPOUT_RATE=0.5
NUM_FILL_GRAY = 125.0

# Base Model choice
NUM_CHOICE_DENSENET169 = 1

# %%
#
# DATA AUGMENTATION:  
# Augment the train data to make sure each EPOCH does NOT train on same image
# i.e. train data will be augmented on every epoch
#
train = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=NUM_VAL_SPLIT,
                           rotation_range=40,
                           zoom_range=NUM_VAL_SPLIT,
#                           width_shift_range=NUM_VAL_SPLIT, 
#                           height_shift_range=NUM_VAL_SPLIT,
#                           fill_mode='constant', 
#                           cval=NUM_FILL_GRAY,                            
                           horizontal_flip=True, 
                           vertical_flip=True, 
                           rescale=NUM_IMG_RESCALE)

val = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)
test = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)

train_dataset = train.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='training')

val_dataset = val.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='validation')

test_dataset = test.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/test', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical')
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
# All Helper functions
#--------------------------------------------------------------------
# Function Name: f_ad_model_builder
# Description: Build Convolutional Neural Network (CNN) Deep learning model
#              for early diagnosis of Alzheimer's disease
#--------------------------------------------------------------------
def f_ad_model_builder():

  #if base_model_choice == NUM_CHOICE_DENSENET169:

  #Choose CNN based model TL
  # Set include tope=False, so fully-connected output layers of the model used to make predictions is not loaded, allowing a new output layer to be added and trained
  model_vgg19 = VGG19(input_shape=(NUM_IMAGE_SIZE,NUM_IMAGE_SIZE,3), include_top=False, weights="imagenet")

  # freeze layers
  for layer in model_vgg19.layers :
    layer.trainable = False

  model = Sequential() # seq model is a linear stacks of layers
  model.add(model_vgg19)

  # Dropout to prevent overfitting
  # Train model on some layer outputs are randomly ignored or “dropped out.” 
  # This has the effect of making the layer look-like and be treated-like a layer with a different 
  # number of nodes and connectivity to the prior layer.
  model.add(Dropout(rate=0.5))

  # Flatten: Rectangular or cubic shapes can't be direct inputs & connected layer. 
  # We flatten the output of the convolutional layers to create a 1-dimentional array (single long feature vector)
  model.add(Flatten())

  # Dense Layer 1 
  model.add(BatchNormalization()) # Batch Normalization: to imporve the training speed
  model.add(Dense(units=2048, kernel_initializer='he_uniform'))

  # Dense Layer 2
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(rate=0.5))
  model.add(Dense(units=1024, kernel_initializer='he_uniform'))

  # Final Dense Layer
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(rate=0.5))
  model.add(Dense(units=4, activation='softmax'))

  # printout whole model: Hidden layer + Dense Layer
  model.summary()
 
  #
  # COMPILE: Choose learning rate from 0.01, 0.001, or 0.0001 i.e. [1e-2, 1e-3, 1e-4]
  # Optimizer: optimizers shape and mold your model into its most accurate possible form by manipulating weights
  model.compile(optimizer = keras.optimizers.Adam(learning_rate = NUM_LEARNING_RATE),
                loss = 'categorical_crossentropy', 
                metrics = [tf.keras.metrics.AUC(name = 'auc')])
  
  return model

#--------------------------------------------------------------------
# Function Name: f_all_ad_plot_model
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_all_plot_model(hist):

    plt.plot(hist.history["acc"])
    plt.plot(hist.history['val_acc'])
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title("AD Early Detection Model Accuracy")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.legend(["Training Accuracy","Validation Accuracy","Training loss","Validation Loss"])

    # Show the plot
    plt.show()

#--------------------------------------------------------------------
# Function Name: f_ad_plot_auc_loss
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_plot_auc_loss(f_model):

  # create subplots
  fig, axs = plt.subplots(1,2,figsize=(15,10))

  ticks = np.arange(1,len(f_model.history['loss'])+1)
  history_auc_length = len(f_model.history['auc'])+1
  history_val_auc_length = len(f_model.history['val_auc'])+1
  history_loss_length = len(f_model.history['loss'])+1
  history_val_loss_length = len(f_model.history['val_loss'])+1

  # Summarize history for auc
  axs[0].plot(range(1,history_auc_length), f_model.history['auc'])
  axs[0].plot(range(1,history_val_auc_length), f_model.history['val_auc'])
  axs[0].set_title('Model AUC')
  axs[0].set_ylabel('AUC')
  axs[0].set_xlabel('Epoch')
  axs[0].set_xticks(ticks,len(f_model.history['auc'])/10)
  axs[0].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

  # Summarize history for loss
  axs[1].plot(range(1, history_loss_length), f_model.history['loss'])
  axs[1].plot(range(1,history_val_loss_length), f_model.history['val_loss'])
  axs[1].set_title('Model Loss')
  axs[1].set_ylabel('Loss')
  axs[1].set_xlabel('Epoch')
  axs[1].set_xticks(ticks,len(f_model.history['loss'])/10)
  axs[1].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

#--------------------------------------------------------------------
# Function Name: 
# Description: 
#              
#--------------------------------------------------------------------
# ??? how to calculate fpr/tpr
def f_ad_plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, 'b',color='orange', label='AUC = %0.2f' % roc_auc)
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate (FPR) ')
    plt.ylabel('True Positive Rate (TPR) ')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc = 'lower right')
    plt.show()
#--------------------------------------------------------------------
# Function Name: f_ad_plot_model
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_plot_acc_loss(f_model):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,10))
    ticks = np.arange(1,len(f_model.history['loss'])+1)
    history_acc_length = len(f_model.history['accuracy'])+1
    history_val_accuracy_length = len(f_model.history['val_accuracy'])+1
    history_loss_length = len(f_model.history['loss'])+1
    history_val_loss_length = len(f_model.history['val_loss'])+1

    # Summarize history for accuracy
    axs[0].plot(range(1,history_acc_length), f_model.history['accuracy'])
    axs[0].plot(range(1,history_val_accuracy_length), f_model.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(ticks,len(f_model.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Summarize history for loss
    axs[1].plot(range(1, history_loss_length), f_model.history['loss'])
    axs[1].plot(range(1,history_val_loss_length), f_model.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(ticks,len(f_model.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()

# %%
# build model with Choice of base Model
model = f_ad_model_builder()

# Define callbacks
checkpoint = ModelCheckpoint("/content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5", monitor='val_auc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_auc', min_delta=0, patience=NUM_PATIENCE, verbose=1, mode='max') 

model_history=model.fit(train_dataset,
                        validation_data=val_dataset,
                        epochs = NUM_EPOCH,
                        callbacks = [checkpoint, early],
                        verbose = 2)

print('--------------------------------------------\n')
print('Results [with VGG19] :')
f_ad_plot_auc_loss(model_history)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25088)             100352
# _________________________________________________________________
# dense (Dense)                (None, 2048)              51382272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 73,621,572
# Trainable params: 53,540,868
# Non-trainable params: 20,080,704
# _________________________________________________________________
# Epoch 1/100
# 33/33 - 1910s - loss: 1.4081 - auc: 0.7585 - val_loss: 1.3412 - val_auc: 0.6790
#
# Epoch 00001: val_auc improved from -inf to 0.67902, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 2/100
# 33/33 - 59s - loss: 1.1781 - auc: 0.8086 - val_loss: 1.1414 - val_auc: 0.7404
#
# Epoch 00002: val_auc improved from 0.67902 to 0.74045, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 3/100
# 33/33 - 59s - loss: 1.1006 - auc: 0.8161 - val_loss: 1.1557 - val_auc: 0.7416
#
# Epoch 00003: val_auc improved from 0.74045 to 0.74163, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 4/100
# 33/33 - 59s - loss: 1.0531 - auc: 0.8256 - val_loss: 1.2080 - val_auc: 0.7143
#
# Epoch 00004: val_auc did not improve from 0.74163
# Epoch 5/100
# 33/33 - 57s - loss: 0.9867 - auc: 0.8397 - val_loss: 1.0204 - val_auc: 0.7967
#
# Epoch 00005: val_auc improved from 0.74163 to 0.79672, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 6/100
# 33/33 - 58s - loss: 0.9708 - auc: 0.8430 - val_loss: 1.0957 - val_auc: 0.7816
#
# Epoch 00006: val_auc did not improve from 0.79672
# Epoch 7/100
# 33/33 - 57s - loss: 0.9618 - auc: 0.8453 - val_loss: 1.1038 - val_auc: 0.7787
#
# Epoch 00007: val_auc did not improve from 0.79672
# Epoch 8/100
# 33/33 - 57s - loss: 0.9091 - auc: 0.8581 - val_loss: 1.0864 - val_auc: 0.8052
#
# Epoch 00008: val_auc improved from 0.79672 to 0.80518, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 9/100
# 33/33 - 58s - loss: 0.8869 - auc: 0.8625 - val_loss: 1.0524 - val_auc: 0.8028
#
# Epoch 00009: val_auc did not improve from 0.80518
# Epoch 10/100
# 33/33 - 57s - loss: 0.8977 - auc: 0.8568 - val_loss: 1.0471 - val_auc: 0.8022
#
# Epoch 00010: val_auc did not improve from 0.80518
# Epoch 11/100
# 33/33 - 57s - loss: 0.8784 - auc: 0.8632 - val_loss: 1.0328 - val_auc: 0.8145
#
# Epoch 00011: val_auc improved from 0.80518 to 0.81452, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 12/100
# 33/33 - 58s - loss: 0.8503 - auc: 0.8696 - val_loss: 1.1026 - val_auc: 0.7963
#
# Epoch 00012: val_auc did not improve from 0.81452
# Epoch 13/100
# 33/33 - 57s - loss: 0.8245 - auc: 0.8763 - val_loss: 1.0867 - val_auc: 0.7925
#
# Epoch 00013: val_auc did not improve from 0.81452
# Epoch 14/100
# 33/33 - 56s - loss: 0.8147 - auc: 0.8802 - val_loss: 1.1223 - val_auc: 0.7848
#
# Epoch 00014: val_auc did not improve from 0.81452
# Epoch 15/100
# 33/33 - 57s - loss: 0.8143 - auc: 0.8784 - val_loss: 0.9777 - val_auc: 0.8234
#
# Epoch 00015: val_auc improved from 0.81452 to 0.82343, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 16/100
# 33/33 - 58s - loss: 0.7965 - auc: 0.8847 - val_loss: 1.0463 - val_auc: 0.8055
#
# Epoch 00016: val_auc did not improve from 0.82343
# Epoch 17/100
# 33/33 - 56s - loss: 0.7954 - auc: 0.8829 - val_loss: 1.0499 - val_auc: 0.8145
#
# Epoch 00017: val_auc did not improve from 0.82343
# Epoch 18/100
# 33/33 - 57s - loss: 0.7952 - auc: 0.8847 - val_loss: 1.1427 - val_auc: 0.7976
#
# Epoch 00018: val_auc did not improve from 0.82343
# Epoch 19/100
# 33/33 - 57s - loss: 0.7761 - auc: 0.8887 - val_loss: 1.1853 - val_auc: 0.7757
#
# Epoch 00019: val_auc did not improve from 0.82343
# Epoch 20/100
# 33/33 - 57s - loss: 0.8021 - auc: 0.8822 - val_loss: 1.1310 - val_auc: 0.7820
#
# Epoch 00020: val_auc did not improve from 0.82343
# Epoch 21/100
# 33/33 - 57s - loss: 0.7701 - auc: 0.8898 - val_loss: 1.0994 - val_auc: 0.7983
#
# Epoch 00021: val_auc did not improve from 0.82343
# Epoch 22/100
# 33/33 - 57s - loss: 0.7764 - auc: 0.8895 - val_loss: 1.0965 - val_auc: 0.8088
#
# Epoch 00022: val_auc did not improve from 0.82343
# Epoch 23/100
# 33/33 - 58s - loss: 0.7657 - auc: 0.8919 - val_loss: 1.0510 - val_auc: 0.8261
#
# Epoch 00023: val_auc improved from 0.82343 to 0.82611, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 24/100
# 33/33 - 59s - loss: 0.7666 - auc: 0.8908 - val_loss: 1.0980 - val_auc: 0.8062
#
# Epoch 00024: val_auc did not improve from 0.82611
# Epoch 25/100
# 33/33 - 57s - loss: 0.7528 - auc: 0.8956 - val_loss: 1.1411 - val_auc: 0.8022
#
# Epoch 00025: val_auc did not improve from 0.82611
# Epoch 26/100
# 33/33 - 57s - loss: 0.7835 - auc: 0.8894 - val_loss: 1.0879 - val_auc: 0.8072
#
# Epoch 00026: val_auc did not improve from 0.82611
# Epoch 27/100
# 33/33 - 57s - loss: 0.7220 - auc: 0.9035 - val_loss: 1.1182 - val_auc: 0.7990
#
# Epoch 00027: val_auc did not improve from 0.82611
# Epoch 28/100
# 33/33 - 58s - loss: 0.7287 - auc: 0.9012 - val_loss: 1.1858 - val_auc: 0.7856
#
# Epoch 00028: val_auc did not improve from 0.82611
# Epoch 29/100
# 33/33 - 58s - loss: 0.7387 - auc: 0.8995 - val_loss: 1.1284 - val_auc: 0.8156
#
# Epoch 00029: val_auc did not improve from 0.82611
# Epoch 30/100
# 33/33 - 57s - loss: 0.7424 - auc: 0.8986 - val_loss: 1.0683 - val_auc: 0.8212
#
# Epoch 00030: val_auc did not improve from 0.82611
# Epoch 31/100
# 33/33 - 57s - loss: 0.7317 - auc: 0.9015 - val_loss: 1.0653 - val_auc: 0.8149
#
# Epoch 00031: val_auc did not improve from 0.82611
# Epoch 32/100
# 33/33 - 57s - loss: 0.7123 - auc: 0.9057 - val_loss: 1.0375 - val_auc: 0.8358
#
# Epoch 00032: val_auc improved from 0.82611 to 0.83575, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 33/100
# 33/33 - 59s - loss: 0.7105 - auc: 0.9069 - val_loss: 1.0488 - val_auc: 0.8220
#
# Epoch 00033: val_auc did not improve from 0.83575
# Epoch 34/100
# 33/33 - 58s - loss: 0.7146 - auc: 0.9071 - val_loss: 1.0328 - val_auc: 0.8299
#
# Epoch 00034: val_auc did not improve from 0.83575
# Epoch 35/100
# 33/33 - 57s - loss: 0.7065 - auc: 0.9082 - val_loss: 1.0657 - val_auc: 0.8181
#
# Epoch 00035: val_auc did not improve from 0.83575
# Epoch 36/100
# 33/33 - 57s - loss: 0.7043 - auc: 0.9087 - val_loss: 1.0102 - val_auc: 0.8309
#
# Epoch 00036: val_auc did not improve from 0.83575
# Epoch 37/100
# 33/33 - 58s - loss: 0.6819 - auc: 0.9134 - val_loss: 1.0264 - val_auc: 0.8278
#
# Epoch 00037: val_auc did not improve from 0.83575
# Epoch 38/100
# 33/33 - 57s - loss: 0.7113 - auc: 0.9064 - val_loss: 1.1094 - val_auc: 0.8170
#
# Epoch 00038: val_auc did not improve from 0.83575
# Epoch 39/100
# 33/33 - 58s - loss: 0.6905 - auc: 0.9116 - val_loss: 1.1280 - val_auc: 0.7982
#
# Epoch 00039: val_auc did not improve from 0.83575
# Epoch 40/100
# 33/33 - 57s - loss: 0.7004 - auc: 0.9094 - val_loss: 1.1394 - val_auc: 0.8255
#
# Epoch 00040: val_auc did not improve from 0.83575
# Epoch 41/100
# 33/33 - 57s - loss: 0.6914 - auc: 0.9127 - val_loss: 1.0061 - val_auc: 0.8364
#
# Epoch 00041: val_auc improved from 0.83575 to 0.83640, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 42/100
# 33/33 - 59s - loss: 0.6895 - auc: 0.9110 - val_loss: 1.0023 - val_auc: 0.8337
#
# Epoch 00042: val_auc did not improve from 0.83640
# Epoch 43/100
# 33/33 - 57s - loss: 0.7093 - auc: 0.9071 - val_loss: 1.0339 - val_auc: 0.8423
#
# Epoch 00043: val_auc improved from 0.83640 to 0.84233, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 44/100
# 33/33 - 59s - loss: 0.6840 - auc: 0.9131 - val_loss: 1.0931 - val_auc: 0.8322
#
# Epoch 00044: val_auc did not improve from 0.84233
# Epoch 45/100
# 33/33 - 58s - loss: 0.6979 - auc: 0.9102 - val_loss: 1.1250 - val_auc: 0.8123
#
# Epoch 00045: val_auc did not improve from 0.84233
# Epoch 46/100
# 33/33 - 57s - loss: 0.6697 - auc: 0.9171 - val_loss: 1.1043 - val_auc: 0.8142
#
# Epoch 00046: val_auc did not improve from 0.84233
# Epoch 47/100
# 33/33 - 59s - loss: 0.6665 - auc: 0.9185 - val_loss: 1.1301 - val_auc: 0.8096
#
# Epoch 00047: val_auc did not improve from 0.84233
# Epoch 48/100
# 33/33 - 59s - loss: 0.6750 - auc: 0.9157 - val_loss: 1.0062 - val_auc: 0.8383
#
# Epoch 00048: val_auc did not improve from 0.84233
# Epoch 49/100
# 33/33 - 58s - loss: 0.6599 - auc: 0.9198 - val_loss: 1.0745 - val_auc: 0.8276
#
# Epoch 00049: val_auc did not improve from 0.84233
# Epoch 50/100
# 33/33 - 59s - loss: 0.6549 - auc: 0.9206 - val_loss: 1.0840 - val_auc: 0.8299
#
# Epoch 00050: val_auc did not improve from 0.84233
# Epoch 51/100
# 33/33 - 59s - loss: 0.6482 - auc: 0.9225 - val_loss: 0.9940 - val_auc: 0.8530
#
# Epoch 00051: val_auc improved from 0.84233 to 0.85295, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 52/100
# 33/33 - 61s - loss: 0.6644 - auc: 0.9195 - val_loss: 0.9926 - val_auc: 0.8460
#
# Epoch 00052: val_auc did not improve from 0.85295
# Epoch 53/100
# 33/33 - 58s - loss: 0.6538 - auc: 0.9213 - val_loss: 0.9558 - val_auc: 0.8511
#
# Epoch 00053: val_auc did not improve from 0.85295
# Epoch 54/100
# 33/33 - 58s - loss: 0.6507 - auc: 0.9222 - val_loss: 0.9020 - val_auc: 0.8708
#
# Epoch 00054: val_auc improved from 0.85295 to 0.87079, saving model to /content/drive/My Drive/AD_proj/my_best_models/vgg19_rev0.hdf5
# Epoch 55/100
# 33/33 - 61s - loss: 0.6563 - auc: 0.9208 - val_loss: 1.0350 - val_auc: 0.8481
#
# Epoch 00055: val_auc did not improve from 0.87079
# Epoch 56/100
# 33/33 - 59s - loss: 0.6418 - auc: 0.9232 - val_loss: 0.9914 - val_auc: 0.8513
#
# Epoch 00056: val_auc did not improve from 0.87079
# Epoch 57/100
# 33/33 - 58s - loss: 0.6150 - auc: 0.9298 - val_loss: 1.0357 - val_auc: 0.8433
#
# Epoch 00057: val_auc did not improve from 0.87079
# Epoch 58/100
# 33/33 - 59s - loss: 0.6509 - auc: 0.9220 - val_loss: 1.0451 - val_auc: 0.8347
#
# Epoch 00058: val_auc did not improve from 0.87079
# Epoch 59/100
# 33/33 - 58s - loss: 0.6338 - auc: 0.9258 - val_loss: 1.0442 - val_auc: 0.8326
#
# Epoch 00059: val_auc did not improve from 0.87079
# Epoch 60/100
# 33/33 - 59s - loss: 0.6600 - auc: 0.9194 - val_loss: 1.0062 - val_auc: 0.8357
#
# Epoch 00060: val_auc did not improve from 0.87079
# Epoch 61/100
# 33/33 - 58s - loss: 0.6435 - auc: 0.9236 - val_loss: 0.9776 - val_auc: 0.8524
#
# Epoch 00061: val_auc did not improve from 0.87079
# Epoch 62/100
# 33/33 - 57s - loss: 0.6252 - auc: 0.9275 - val_loss: 1.0916 - val_auc: 0.8415
#
# Epoch 00062: val_auc did not improve from 0.87079
# Epoch 63/100
# 33/33 - 57s - loss: 0.6237 - auc: 0.9283 - val_loss: 1.0039 - val_auc: 0.8547
#
# Epoch 00063: val_auc did not improve from 0.87079
# Epoch 64/100
# 33/33 - 57s - loss: 0.6442 - auc: 0.9243 - val_loss: 1.0260 - val_auc: 0.8446
#
# Epoch 00064: val_auc did not improve from 0.87079
# Epoch 65/100
# 33/33 - 58s - loss: 0.6280 - auc: 0.9271 - val_loss: 0.9579 - val_auc: 0.8632
#
# Epoch 00065: val_auc did not improve from 0.87079
# Epoch 66/100
# 33/33 - 58s - loss: 0.6311 - auc: 0.9269 - val_loss: 1.0613 - val_auc: 0.8529
#
# Epoch 00066: val_auc did not improve from 0.87079
# Epoch 67/100
# 33/33 - 59s - loss: 0.6178 - auc: 0.9292 - val_loss: 1.0198 - val_auc: 0.8541
#
# Epoch 00067: val_auc did not improve from 0.87079
# Epoch 68/100
# 33/33 - 59s - loss: 0.6223 - auc: 0.9292 - val_loss: 0.9919 - val_auc: 0.8523
#
# Epoch 00068: val_auc did not improve from 0.87079
# Epoch 69/100
# 33/33 - 59s - loss: 0.6196 - auc: 0.9293 - val_loss: 1.0263 - val_auc: 0.8571
#
# Epoch 00069: val_auc did not improve from 0.87079
# Epoch 70/100
# 33/33 - 60s - loss: 0.6079 - auc: 0.9323 - val_loss: 1.0562 - val_auc: 0.8427
#
# Epoch 00070: val_auc did not improve from 0.87079
# Epoch 71/100
# 33/33 - 61s - loss: 0.6077 - auc: 0.9320 - val_loss: 0.9952 - val_auc: 0.8519
#
# Epoch 00071: val_auc did not improve from 0.87079
# Epoch 72/100
# 33/33 - 60s - loss: 0.6121 - auc: 0.9309 - val_loss: 0.9926 - val_auc: 0.8567
#
# Epoch 00072: val_auc did not improve from 0.87079
# Epoch 73/100
# 33/33 - 60s - loss: 0.6217 - auc: 0.9291 - val_loss: 0.9767 - val_auc: 0.8627
#
# Epoch 00073: val_auc did not improve from 0.87079
# Epoch 74/100
# 33/33 - 60s - loss: 0.6280 - auc: 0.9269 - val_loss: 1.0979 - val_auc: 0.8418
#
# Epoch 00074: val_auc did not improve from 0.87079
# Epoch 00074: early stopping
# --------------------------------------------
#
# Results [with VGG19] :
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:107: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:116: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
