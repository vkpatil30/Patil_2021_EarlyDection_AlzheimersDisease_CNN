# %% [markdown]
# Project: # Patil_ADEarlyDetection
#
# # **Phase 2:**
# ## CNN with TL = DenseNet201
#
#
# ## **Exp 11**
# ### Densenet201
# ### Matrix =auc
# ### acc monitor =val_acc
# ### LR=0.0001
# ### No AUG
# ###  Noise = 0.3
# ### EPOCH 200 (EarlyStp=30)
# ### CategoricalAccuracy
# ### Train Dataset = original

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/My Drive/AD_proj"

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model, save_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D, GaussianNoise
from keras.metrics import AUC, Accuracy, CategoricalAccuracy
from keras.optimizers import Adam
from keras.applications.densenet import preprocess_input, decode_predictions
from keras.applications.densenet import DenseNet201
from keras.callbacks import EarlyStopping, ModelCheckpoint


import numpy as np
import IPython
import itertools

# Plot libs
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import sklearn
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

import sys
sys.path.append('/content/drive/My Drive/AD_proj')

#
# Define constants
#
NUM_EPOCH = 200 #200
NUM_PATIENCE = 30 #30
NUM_VAL_SPLIT = 0.2
NUM_IMG_RESCALE = 1/255
NUM_BATCH_SIZE = 128
NUM_IMAGE_SIZE = 224
NUM_LEARNING_RATE = 0.0001
ad_model_filename = "/content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5"

target_names = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
# Data augmentation to avoid overfitting
train = ImageDataGenerator(validation_split=NUM_VAL_SPLIT,
                           rotation_range=90,
                           zoom_range=0.2,
                           horizontal_flip=True, 
                           vertical_flip=True, 
                           width_shift_range = 0.1,
                           height_shift_range =0.1,
                           rescale=NUM_IMG_RESCALE)

train = ImageDataGenerator(validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)
validation = ImageDataGenerator(validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)

test = ImageDataGenerator(rescale=NUM_IMG_RESCALE)

train_dataset = train.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='training')
val_dataset = validation.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='validation')

test_dataset = test.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/test', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical')
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
train_dataset.class_indices
# Out:
# {'MildDemented': 0,
#  'ModerateDemented': 1,
#  'NonDemented': 2,
#  'VeryMildDemented': 3}

# %%
#--------------------------------------------------------------------
# Function Name: f_ad_model_builder
# Description: Build Convolutional Neural Network (CNN) Deep learning model
#              for early diagnosis of Alzheimer's disease
# Output : 4 output classes 

# Activation function RELU:
# The rectified linear activation function or ReLU for short is a piecewise 
# linear function that will output the input directly if it is positive, 
# otherwise, it will output zero. It has become the default activation function 
# for many types of neural networks because a model that uses it is easier to train 
# and often achieves better performance.
#
#--------------------------------------------------------------------
def f_ad_model_builder():
    
  # 
  # Keras Model Instantiation
  # From https://keras.io/api/applications/: Keras Applications are deep learning models that are 
  # made available alongside pre-trained weights. Weights are downloaded automatically when instantiating a model.
  # It is also known as Transfer layer model
  model_TL = DenseNet201(input_shape=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE, 3), include_top=False, weights="imagenet")

  #print('----------- Transfer Layer ---------\n')
  #model_densenet201.summary()
  #print('------------------------------------\n')

  # freeze layers
  for layer in model_TL.layers :
    layer.trainable = False

  # Kera Sequential model is appropriate for deep neural networks
  model = Sequential()
  model.add(model_TL)

  # Dropout is a regularization technique that prevents neural networks from overfitting
  # It modify the network itself. It randomly drops neurons from the neural network 
  # during training in each iteration.
  model.add(Dropout(0.5)) # dropout few nodes to prevent overfitting

  model.add(Flatten()) 

  model.add(BatchNormalization()) # standardize input to next layer

  # Dense later #1
  model.add(Dense(2048,kernel_initializer='he_uniform'))
  
  model.add(BatchNormalization()) # standardize input to next layer 
  model.add(GaussianNoise(0.3))
  model.add(Activation('relu'))
  model.add(Dropout(0.5)) # dropout few nodes to prevent overfitting

  # Dense later #2
  model.add(Dense(1024,kernel_initializer='he_uniform'))

  model.add(BatchNormalization()) # standardize input to next layer
  model.add(GaussianNoise(0.3))
  model.add(Activation('relu'))
  model.add(Dropout(0.5)) # dropout few nodes to prevent overfitting

  # Dense later #3 (Outout)
  model.add(Dense(4,activation='softmax'))

  model.summary()

  #
  # COMPILE: Tune the learning rate for the optimizer value choice 
  # from 0.01, 0.001, or 0.0001
  # 
  model.compile(optimizer = Adam(learning_rate = NUM_LEARNING_RATE),
                loss = 'categorical_crossentropy', 
                metrics = [AUC(name = 'auc', multi_label=True), CategoricalAccuracy(name = 'accuracy')])

  # metrics=['mae', 'acc']
  
  return model

#--------------------------------------------------------------------
# Function Name: f_ad_plot_auc_loss
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_plot_auc_loss(f_model):

  # create subplots
  fig, axs = plt.subplots(1,3,figsize=(15,10))

  ticks = np.arange(1,len(f_model.history['loss'])+1)
  history_acc_length = len(f_model.history['accuracy'])+1
  history_val_acc_length = len(f_model.history['val_accuracy'])+1
  history_auc_length = len(f_model.history['auc'])+1
  history_val_auc_length = len(f_model.history['val_auc'])+1
  history_loss_length = len(f_model.history['loss'])+1
  history_val_loss_length = len(f_model.history['val_loss'])+1

  # Summarize history for ACC
  axs[0].plot(range(1,history_acc_length), f_model.history['accuracy'])
  axs[0].plot(range(1,history_val_acc_length), f_model.history['val_accuracy'])
  axs[0].set_title('MODEL ACCURACY')
  axs[0].set_ylabel('ACC')
  axs[0].set_xlabel('Epoch')
  axs[0].set_xticks(ticks,len(f_model.history['accuracy'])/10)
  axs[0].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

  # Summarize history for AUC
  axs[1].plot(range(1,history_auc_length), f_model.history['auc'])
  axs[1].plot(range(1,history_val_auc_length), f_model.history['val_auc'])
  axs[1].set_title('Model Area Under Curve - AUC')
  axs[1].set_ylabel('AUC')
  axs[1].set_xlabel('Epoch')
  axs[1].set_xticks(ticks,len(f_model.history['auc'])/10)
  axs[1].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

  # Summarize history for loss
  axs[2].plot(range(1, history_loss_length), f_model.history['loss'])
  axs[2].plot(range(1,history_val_loss_length), f_model.history['val_loss'])
  axs[2].set_title('Model Loss')
  axs[2].set_ylabel('Loss')
  axs[2].set_xlabel('Epoch')
  axs[2].set_xticks(ticks,len(f_model.history['loss'])/10)
  axs[2].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

#--------------------------------------------------------------------
# Function Name: plot_confusion_matrix
# Description: 
# source code from : scikit-learn.org
#--------------------------------------------------------------------
def f_ad_plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=90)
  plt.yticks(tick_marks, classes)

  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  print(cm)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')

# %%
checkpoint = ModelCheckpoint(ad_model_filename, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=NUM_PATIENCE, verbose=1, mode='max') 

model = f_ad_model_builder()

class_weights = compute_class_weight('balanced', np.unique(test_dataset.classes), np.array(test_dataset.classes))
d_class_weights = dict(enumerate(class_weights))

model_history = model.fit(train_dataset,
                        validation_data = val_dataset,
                        epochs = NUM_EPOCH,
                        class_weight = d_class_weights,
                        callbacks = [checkpoint, early])

print('--------------------------------------------\n')
print('Results:')
f_ad_plot_auc_loss(model_history)

#!ls -al '/content/drive/My Drive/AD_proj/my_best_models'
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Functional)     (None, 7, 7, 1920)        18321984
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1920)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 94080)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 94080)             376320
# _________________________________________________________________
# dense (Dense)                (None, 2048)              192677888
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 2048)              0
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 213,490,756
# Trainable params: 194,974,468
# Non-trainable params: 18,516,288
# _________________________________________________________________
# Epoch 1/200
# 33/33 [==============================] - 1170s 36s/step - loss: 1.4627 - auc: 0.6762 - accuracy: 0.4312 - val_loss: 2.8824 - val_auc: 0.5401 - val_accuracy: 0.3617
#
# Epoch 00001: val_accuracy improved from -inf to 0.36168, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 2/200
# 33/33 [==============================] - 40s 1s/step - loss: 0.7952 - auc: 0.8678 - accuracy: 0.5793 - val_loss: 1.6461 - val_auc: 0.5760 - val_accuracy: 0.3988
#
# Epoch 00002: val_accuracy improved from 0.36168 to 0.39883, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 3/200
# 33/33 [==============================] - 43s 1s/step - loss: 0.5301 - auc: 0.9242 - accuracy: 0.7035 - val_loss: 1.3792 - val_auc: 0.6651 - val_accuracy: 0.4409
#
# Epoch 00003: val_accuracy improved from 0.39883 to 0.44086, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 4/200
# 33/33 [==============================] - 42s 1s/step - loss: 0.4043 - auc: 0.9527 - accuracy: 0.7831 - val_loss: 1.2090 - val_auc: 0.7552 - val_accuracy: 0.4819
#
# Epoch 00004: val_accuracy improved from 0.44086 to 0.48192, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 5/200
# 33/33 [==============================] - 40s 1s/step - loss: 0.3092 - auc: 0.9627 - accuracy: 0.8388 - val_loss: 1.2714 - val_auc: 0.7627 - val_accuracy: 0.4946
#
# Epoch 00005: val_accuracy improved from 0.48192 to 0.49462, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 6/200
# 33/33 [==============================] - 38s 1s/step - loss: 0.2267 - auc: 0.9806 - accuracy: 0.8734 - val_loss: 1.0929 - val_auc: 0.8043 - val_accuracy: 0.5533
#
# Epoch 00006: val_accuracy improved from 0.49462 to 0.55327, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 7/200
# 33/33 [==============================] - 40s 1s/step - loss: 0.2201 - auc: 0.9691 - accuracy: 0.8925 - val_loss: 1.0782 - val_auc: 0.8208 - val_accuracy: 0.5826
#
# Epoch 00007: val_accuracy improved from 0.55327 to 0.58260, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 8/200
# 33/33 [==============================] - 41s 1s/step - loss: 0.1696 - auc: 0.9903 - accuracy: 0.9113 - val_loss: 1.0133 - val_auc: 0.8442 - val_accuracy: 0.6041
#
# Epoch 00008: val_accuracy improved from 0.58260 to 0.60411, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 9/200
# 33/33 [==============================] - 39s 1s/step - loss: 0.1242 - auc: 0.9945 - accuracy: 0.9387 - val_loss: 1.0381 - val_auc: 0.8454 - val_accuracy: 0.6002
#
# Epoch 00009: val_accuracy did not improve from 0.60411
# Epoch 10/200
# 33/33 [==============================] - 27s 798ms/step - loss: 0.1049 - auc: 0.9886 - accuracy: 0.9473 - val_loss: 1.0167 - val_auc: 0.8566 - val_accuracy: 0.6325
#
# Epoch 00010: val_accuracy improved from 0.60411 to 0.63245, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 11/200
# 33/33 [==============================] - 38s 1s/step - loss: 0.0857 - auc: 0.9831 - accuracy: 0.9568 - val_loss: 0.9886 - val_auc: 0.8673 - val_accuracy: 0.6354
#
# Epoch 00011: val_accuracy improved from 0.63245 to 0.63539, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 12/200
# 33/33 [==============================] - 39s 1s/step - loss: 0.0937 - auc: 0.9963 - accuracy: 0.9520 - val_loss: 0.9469 - val_auc: 0.8797 - val_accuracy: 0.6559
#
# Epoch 00012: val_accuracy improved from 0.63539 to 0.65591, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 13/200
# 33/33 [==============================] - 39s 1s/step - loss: 0.0877 - auc: 0.9977 - accuracy: 0.9650 - val_loss: 0.9981 - val_auc: 0.8772 - val_accuracy: 0.6520
#
# Epoch 00013: val_accuracy did not improve from 0.65591
# Epoch 14/200
# 33/33 [==============================] - 26s 794ms/step - loss: 0.0644 - auc: 0.9986 - accuracy: 0.9679 - val_loss: 0.8957 - val_auc: 0.8963 - val_accuracy: 0.6872
#
# Epoch 00014: val_accuracy improved from 0.65591 to 0.68719, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 15/200
# 33/33 [==============================] - 39s 1s/step - loss: 0.0633 - auc: 0.9986 - accuracy: 0.9703 - val_loss: 0.9313 - val_auc: 0.8879 - val_accuracy: 0.6872
#
# Epoch 00015: val_accuracy did not improve from 0.68719
# Epoch 16/200
# 33/33 [==============================] - 27s 808ms/step - loss: 0.0587 - auc: 0.9989 - accuracy: 0.9753 - val_loss: 0.8489 - val_auc: 0.9075 - val_accuracy: 0.7195
#
# Epoch 00016: val_accuracy improved from 0.68719 to 0.71945, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 17/200
# 33/33 [==============================] - 38s 1s/step - loss: 0.0486 - auc: 0.9919 - accuracy: 0.9788 - val_loss: 0.9165 - val_auc: 0.8973 - val_accuracy: 0.7009
#
# Epoch 00017: val_accuracy did not improve from 0.71945
# Epoch 18/200
# 33/33 [==============================] - 27s 810ms/step - loss: 0.0534 - auc: 0.9989 - accuracy: 0.9767 - val_loss: 1.0011 - val_auc: 0.9003 - val_accuracy: 0.6764
#
# Epoch 00018: val_accuracy did not improve from 0.71945
# Epoch 19/200
# 33/33 [==============================] - 26s 775ms/step - loss: 0.0520 - auc: 0.9991 - accuracy: 0.9772 - val_loss: 1.0561 - val_auc: 0.8961 - val_accuracy: 0.6706
#
# Epoch 00019: val_accuracy did not improve from 0.71945
# Epoch 20/200
# 33/33 [==============================] - 25s 791ms/step - loss: 0.0934 - auc: 0.9623 - accuracy: 0.9483 - val_loss: 1.0003 - val_auc: 0.8937 - val_accuracy: 0.6891
#
# Epoch 00020: val_accuracy did not improve from 0.71945
# Epoch 21/200
# 33/33 [==============================] - 26s 786ms/step - loss: 0.0447 - auc: 0.9994 - accuracy: 0.9833 - val_loss: 0.9888 - val_auc: 0.9021 - val_accuracy: 0.6950
#
# Epoch 00021: val_accuracy did not improve from 0.71945
# Epoch 22/200
# 33/33 [==============================] - 26s 784ms/step - loss: 0.0481 - auc: 0.9846 - accuracy: 0.9762 - val_loss: 1.1025 - val_auc: 0.8838 - val_accuracy: 0.6667
#
# Epoch 00022: val_accuracy did not improve from 0.71945
# Epoch 23/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0426 - auc: 0.9994 - accuracy: 0.9802 - val_loss: 0.9923 - val_auc: 0.9008 - val_accuracy: 0.7019
#
# Epoch 00023: val_accuracy did not improve from 0.71945
# Epoch 24/200
# 33/33 [==============================] - 26s 780ms/step - loss: 0.0433 - auc: 0.9994 - accuracy: 0.9802 - val_loss: 0.9985 - val_auc: 0.8948 - val_accuracy: 0.6989
#
# Epoch 00024: val_accuracy did not improve from 0.71945
# Epoch 25/200
# 33/33 [==============================] - 26s 782ms/step - loss: 0.0348 - auc: 0.9998 - accuracy: 0.9877 - val_loss: 1.0080 - val_auc: 0.8999 - val_accuracy: 0.6921
#
# Epoch 00025: val_accuracy did not improve from 0.71945
# Epoch 26/200
# 33/33 [==============================] - 26s 784ms/step - loss: 0.0377 - auc: 0.9997 - accuracy: 0.9852 - val_loss: 0.9099 - val_auc: 0.9124 - val_accuracy: 0.7253
#
# Epoch 00026: val_accuracy improved from 0.71945 to 0.72532, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 27/200
# 33/33 [==============================] - 39s 1s/step - loss: 0.0412 - auc: 0.9995 - accuracy: 0.9818 - val_loss: 0.8727 - val_auc: 0.9144 - val_accuracy: 0.7195
#
# Epoch 00027: val_accuracy did not improve from 0.72532
# Epoch 28/200
# 33/33 [==============================] - 27s 801ms/step - loss: 0.0347 - auc: 0.9996 - accuracy: 0.9855 - val_loss: 0.9823 - val_auc: 0.9019 - val_accuracy: 0.7146
#
# Epoch 00028: val_accuracy did not improve from 0.72532
# Epoch 29/200
# 33/33 [==============================] - 25s 769ms/step - loss: 0.0351 - auc: 0.9923 - accuracy: 0.9874 - val_loss: 0.8053 - val_auc: 0.9246 - val_accuracy: 0.7498
#
# Epoch 00029: val_accuracy improved from 0.72532 to 0.74976, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 30/200
# 33/33 [==============================] - 39s 1s/step - loss: 0.0331 - auc: 0.9994 - accuracy: 0.9867 - val_loss: 0.8116 - val_auc: 0.9235 - val_accuracy: 0.7488
#
# Epoch 00030: val_accuracy did not improve from 0.74976
# Epoch 31/200
# 33/33 [==============================] - 27s 804ms/step - loss: 0.0317 - auc: 0.9997 - accuracy: 0.9878 - val_loss: 0.8772 - val_auc: 0.9161 - val_accuracy: 0.7341
#
# Epoch 00031: val_accuracy did not improve from 0.74976
# Epoch 32/200
# 33/33 [==============================] - 26s 774ms/step - loss: 0.0252 - auc: 0.9925 - accuracy: 0.9890 - val_loss: 0.9562 - val_auc: 0.9078 - val_accuracy: 0.7214
#
# Epoch 00032: val_accuracy did not improve from 0.74976
# Epoch 33/200
# 33/33 [==============================] - 26s 775ms/step - loss: 0.0276 - auc: 0.9997 - accuracy: 0.9898 - val_loss: 0.9402 - val_auc: 0.9088 - val_accuracy: 0.7283
#
# Epoch 00033: val_accuracy did not improve from 0.74976
# Epoch 34/200
# 33/33 [==============================] - 26s 789ms/step - loss: 0.0286 - auc: 0.9924 - accuracy: 0.9885 - val_loss: 0.9692 - val_auc: 0.9058 - val_accuracy: 0.7165
#
# Epoch 00034: val_accuracy did not improve from 0.74976
# Epoch 35/200
# 33/33 [==============================] - 26s 786ms/step - loss: 0.0263 - auc: 0.9998 - accuracy: 0.9896 - val_loss: 0.9378 - val_auc: 0.9068 - val_accuracy: 0.7087
#
# Epoch 00035: val_accuracy did not improve from 0.74976
# Epoch 36/200
# 33/33 [==============================] - 26s 775ms/step - loss: 0.0240 - auc: 0.9999 - accuracy: 0.9899 - val_loss: 0.9051 - val_auc: 0.9123 - val_accuracy: 0.7331
#
# Epoch 00036: val_accuracy did not improve from 0.74976
# Epoch 37/200
# 33/33 [==============================] - 26s 797ms/step - loss: 0.0435 - auc: 0.9850 - accuracy: 0.9744 - val_loss: 0.9404 - val_auc: 0.9053 - val_accuracy: 0.7214
#
# Epoch 00037: val_accuracy did not improve from 0.74976
# Epoch 38/200
# 33/33 [==============================] - 26s 782ms/step - loss: 0.0224 - auc: 0.9999 - accuracy: 0.9910 - val_loss: 0.8673 - val_auc: 0.9164 - val_accuracy: 0.7458
#
# Epoch 00038: val_accuracy did not improve from 0.74976
# Epoch 39/200
# 33/33 [==============================] - 26s 779ms/step - loss: 0.0230 - auc: 0.9998 - accuracy: 0.9925 - val_loss: 0.8424 - val_auc: 0.9199 - val_accuracy: 0.7527
#
# Epoch 00039: val_accuracy improved from 0.74976 to 0.75269, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 40/200
# 33/33 [==============================] - 40s 1s/step - loss: 0.0210 - auc: 0.9852 - accuracy: 0.9908 - val_loss: 0.8193 - val_auc: 0.9231 - val_accuracy: 0.7556
#
# Epoch 00040: val_accuracy improved from 0.75269 to 0.75562, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 41/200
# 33/33 [==============================] - 43s 1s/step - loss: 0.0220 - auc: 0.9998 - accuracy: 0.9926 - val_loss: 0.9176 - val_auc: 0.9096 - val_accuracy: 0.7283
#
# Epoch 00041: val_accuracy did not improve from 0.75562
# Epoch 42/200
# 33/33 [==============================] - 26s 794ms/step - loss: 0.0201 - auc: 0.9999 - accuracy: 0.9933 - val_loss: 0.8628 - val_auc: 0.9184 - val_accuracy: 0.7449
#
# Epoch 00042: val_accuracy did not improve from 0.75562
# Epoch 43/200
# 33/33 [==============================] - 26s 772ms/step - loss: 0.0207 - auc: 0.9925 - accuracy: 0.9920 - val_loss: 0.9344 - val_auc: 0.9049 - val_accuracy: 0.7263
#
# Epoch 00043: val_accuracy did not improve from 0.75562
# Epoch 44/200
# 33/33 [==============================] - 26s 778ms/step - loss: 0.0227 - auc: 0.9848 - accuracy: 0.9908 - val_loss: 0.8906 - val_auc: 0.9100 - val_accuracy: 0.7361
#
# Epoch 00044: val_accuracy did not improve from 0.75562
# Epoch 45/200
# 33/33 [==============================] - 26s 787ms/step - loss: 0.0229 - auc: 0.9924 - accuracy: 0.9908 - val_loss: 0.9138 - val_auc: 0.9119 - val_accuracy: 0.7312
#
# Epoch 00045: val_accuracy did not improve from 0.75562
# Epoch 46/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0229 - auc: 0.9998 - accuracy: 0.9892 - val_loss: 0.8678 - val_auc: 0.9155 - val_accuracy: 0.7478
#
# Epoch 00046: val_accuracy did not improve from 0.75562
# Epoch 47/200
# 33/33 [==============================] - 26s 787ms/step - loss: 0.0205 - auc: 0.9705 - accuracy: 0.9930 - val_loss: 0.8556 - val_auc: 0.9156 - val_accuracy: 0.7488
#
# Epoch 00047: val_accuracy did not improve from 0.75562
# Epoch 48/200
# 33/33 [==============================] - 26s 782ms/step - loss: 0.0198 - auc: 0.9999 - accuracy: 0.9913 - val_loss: 0.9277 - val_auc: 0.9132 - val_accuracy: 0.7380
#
# Epoch 00048: val_accuracy did not improve from 0.75562
# Epoch 49/200
# 33/33 [==============================] - 26s 783ms/step - loss: 0.0211 - auc: 0.9999 - accuracy: 0.9884 - val_loss: 0.9001 - val_auc: 0.9175 - val_accuracy: 0.7458
#
# Epoch 00049: val_accuracy did not improve from 0.75562
# Epoch 50/200
# 33/33 [==============================] - 26s 785ms/step - loss: 0.0186 - auc: 0.9998 - accuracy: 0.9915 - val_loss: 0.8509 - val_auc: 0.9226 - val_accuracy: 0.7595
#
# Epoch 00050: val_accuracy improved from 0.75562 to 0.75953, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 51/200
# 33/33 [==============================] - 40s 1s/step - loss: 0.0170 - auc: 0.9999 - accuracy: 0.9921 - val_loss: 0.9388 - val_auc: 0.9125 - val_accuracy: 0.7439
#
# Epoch 00051: val_accuracy did not improve from 0.75953
# Epoch 52/200
# 33/33 [==============================] - 27s 800ms/step - loss: 0.0174 - auc: 0.9999 - accuracy: 0.9952 - val_loss: 0.9529 - val_auc: 0.9107 - val_accuracy: 0.7400
#
# Epoch 00052: val_accuracy did not improve from 0.75953
# Epoch 53/200
# 33/33 [==============================] - 25s 768ms/step - loss: 0.0157 - auc: 0.9926 - accuracy: 0.9908 - val_loss: 0.8493 - val_auc: 0.9250 - val_accuracy: 0.7693
#
# Epoch 00053: val_accuracy improved from 0.75953 to 0.76931, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_exp11.hdf5
# Epoch 54/200
# 33/33 [==============================] - 40s 1s/step - loss: 0.0145 - auc: 0.9999 - accuracy: 0.9941 - val_loss: 0.9145 - val_auc: 0.9168 - val_accuracy: 0.7478
#
# Epoch 00054: val_accuracy did not improve from 0.76931
# Epoch 55/200
# 33/33 [==============================] - 27s 804ms/step - loss: 0.0147 - auc: 0.9852 - accuracy: 0.9947 - val_loss: 0.9513 - val_auc: 0.9141 - val_accuracy: 0.7449
#
# Epoch 00055: val_accuracy did not improve from 0.76931
# Epoch 56/200
# 33/33 [==============================] - 26s 772ms/step - loss: 0.0140 - auc: 0.9926 - accuracy: 0.9940 - val_loss: 0.9501 - val_auc: 0.9133 - val_accuracy: 0.7419
#
# Epoch 00056: val_accuracy did not improve from 0.76931
# Epoch 57/200
# 33/33 [==============================] - 26s 774ms/step - loss: 0.0122 - auc: 1.0000 - accuracy: 0.9955 - val_loss: 0.9593 - val_auc: 0.9120 - val_accuracy: 0.7380
#
# Epoch 00057: val_accuracy did not improve from 0.76931
# Epoch 58/200
# 33/33 [==============================] - 26s 796ms/step - loss: 0.0218 - auc: 0.9997 - accuracy: 0.9964 - val_loss: 0.9431 - val_auc: 0.9152 - val_accuracy: 0.7468
#
# Epoch 00058: val_accuracy did not improve from 0.76931
# Epoch 59/200
# 33/33 [==============================] - 26s 785ms/step - loss: 0.0181 - auc: 0.9999 - accuracy: 0.9928 - val_loss: 1.0442 - val_auc: 0.9081 - val_accuracy: 0.7331
#
# Epoch 00059: val_accuracy did not improve from 0.76931
# Epoch 60/200
# 33/33 [==============================] - 26s 778ms/step - loss: 0.0150 - auc: 0.9852 - accuracy: 0.9948 - val_loss: 0.9186 - val_auc: 0.9185 - val_accuracy: 0.7605
#
# Epoch 00060: val_accuracy did not improve from 0.76931
# Epoch 61/200
# 33/33 [==============================] - 26s 779ms/step - loss: 0.0132 - auc: 1.0000 - accuracy: 0.9941 - val_loss: 0.9874 - val_auc: 0.9092 - val_accuracy: 0.7458
#
# Epoch 00061: val_accuracy did not improve from 0.76931
# Epoch 62/200
# 33/33 [==============================] - 26s 784ms/step - loss: 0.0150 - auc: 0.9999 - accuracy: 0.9924 - val_loss: 0.9756 - val_auc: 0.9131 - val_accuracy: 0.7439
#
# Epoch 00062: val_accuracy did not improve from 0.76931
# Epoch 63/200
# 33/33 [==============================] - 26s 783ms/step - loss: 0.0135 - auc: 1.0000 - accuracy: 0.9941 - val_loss: 1.0733 - val_auc: 0.9051 - val_accuracy: 0.7341
#
# Epoch 00063: val_accuracy did not improve from 0.76931
# Epoch 64/200
# 33/33 [==============================] - 26s 783ms/step - loss: 0.0103 - auc: 1.0000 - accuracy: 0.9956 - val_loss: 1.0579 - val_auc: 0.9024 - val_accuracy: 0.7292
#
# Epoch 00064: val_accuracy did not improve from 0.76931
# Epoch 65/200
# 33/33 [==============================] - 26s 777ms/step - loss: 0.0114 - auc: 0.9926 - accuracy: 0.9950 - val_loss: 0.9911 - val_auc: 0.9100 - val_accuracy: 0.7322
#
# Epoch 00065: val_accuracy did not improve from 0.76931
# Epoch 66/200
# 33/33 [==============================] - 26s 780ms/step - loss: 0.0135 - auc: 1.0000 - accuracy: 0.9958 - val_loss: 0.9541 - val_auc: 0.9117 - val_accuracy: 0.7361
#
# Epoch 00066: val_accuracy did not improve from 0.76931
# Epoch 67/200
# 33/33 [==============================] - 26s 780ms/step - loss: 0.0142 - auc: 0.9999 - accuracy: 0.9945 - val_loss: 0.9622 - val_auc: 0.9133 - val_accuracy: 0.7449
#
# Epoch 00067: val_accuracy did not improve from 0.76931
# Epoch 68/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0146 - auc: 0.9996 - accuracy: 0.9948 - val_loss: 0.9183 - val_auc: 0.9163 - val_accuracy: 0.7527
#
# Epoch 00068: val_accuracy did not improve from 0.76931
# Epoch 69/200
# 33/33 [==============================] - 26s 780ms/step - loss: 0.0233 - auc: 0.9926 - accuracy: 0.9931 - val_loss: 0.9809 - val_auc: 0.9053 - val_accuracy: 0.7273
#
# Epoch 00069: val_accuracy did not improve from 0.76931
# Epoch 70/200
# 33/33 [==============================] - 26s 783ms/step - loss: 0.0134 - auc: 0.9926 - accuracy: 0.9943 - val_loss: 0.9603 - val_auc: 0.9132 - val_accuracy: 0.7458
#
# Epoch 00070: val_accuracy did not improve from 0.76931
# Epoch 71/200
# 33/33 [==============================] - 26s 782ms/step - loss: 0.0114 - auc: 1.0000 - accuracy: 0.9954 - val_loss: 0.9358 - val_auc: 0.9163 - val_accuracy: 0.7517
#
# Epoch 00071: val_accuracy did not improve from 0.76931
# Epoch 72/200
# 33/33 [==============================] - 26s 783ms/step - loss: 0.0126 - auc: 1.0000 - accuracy: 0.9935 - val_loss: 0.9959 - val_auc: 0.9083 - val_accuracy: 0.7439
#
# Epoch 00072: val_accuracy did not improve from 0.76931
# Epoch 73/200
# 33/33 [==============================] - 26s 801ms/step - loss: 0.0431 - auc: 0.9705 - accuracy: 0.9792 - val_loss: 0.9299 - val_auc: 0.9163 - val_accuracy: 0.7537
#
# Epoch 00073: val_accuracy did not improve from 0.76931
# Epoch 74/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0116 - auc: 0.9926 - accuracy: 0.9950 - val_loss: 0.9747 - val_auc: 0.9087 - val_accuracy: 0.7302
#
# Epoch 00074: val_accuracy did not improve from 0.76931
# Epoch 75/200
# 33/33 [==============================] - 26s 780ms/step - loss: 0.0110 - auc: 0.9926 - accuracy: 0.9962 - val_loss: 0.9719 - val_auc: 0.9112 - val_accuracy: 0.7390
#
# Epoch 00075: val_accuracy did not improve from 0.76931
# Epoch 76/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0101 - auc: 0.9853 - accuracy: 0.9970 - val_loss: 0.9526 - val_auc: 0.9156 - val_accuracy: 0.7449
#
# Epoch 00076: val_accuracy did not improve from 0.76931
# Epoch 77/200
# 33/33 [==============================] - 26s 784ms/step - loss: 0.0128 - auc: 0.9926 - accuracy: 0.9962 - val_loss: 1.0075 - val_auc: 0.9072 - val_accuracy: 0.7302
#
# Epoch 00077: val_accuracy did not improve from 0.76931
# Epoch 78/200
# 33/33 [==============================] - 26s 782ms/step - loss: 0.0083 - auc: 1.0000 - accuracy: 0.9975 - val_loss: 0.9483 - val_auc: 0.9142 - val_accuracy: 0.7537
#
# Epoch 00078: val_accuracy did not improve from 0.76931
# Epoch 79/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0166 - auc: 0.9999 - accuracy: 0.9920 - val_loss: 0.9517 - val_auc: 0.9123 - val_accuracy: 0.7498
#
# Epoch 00079: val_accuracy did not improve from 0.76931
# Epoch 80/200
# 33/33 [==============================] - 26s 783ms/step - loss: 0.0090 - auc: 1.0000 - accuracy: 0.9966 - val_loss: 0.9640 - val_auc: 0.9105 - val_accuracy: 0.7468
#
# Epoch 00080: val_accuracy did not improve from 0.76931
# Epoch 81/200
# 33/33 [==============================] - 26s 784ms/step - loss: 0.0103 - auc: 1.0000 - accuracy: 0.9956 - val_loss: 0.9793 - val_auc: 0.9073 - val_accuracy: 0.7458
#
# Epoch 00081: val_accuracy did not improve from 0.76931
# Epoch 82/200
# 33/33 [==============================] - 26s 781ms/step - loss: 0.0130 - auc: 0.9999 - accuracy: 0.9944 - val_loss: 0.9060 - val_auc: 0.9186 - val_accuracy: 0.7615
#
# Epoch 00082: val_accuracy did not improve from 0.76931
# Epoch 83/200
# 33/33 [==============================] - 26s 779ms/step - loss: 0.0092 - auc: 1.0000 - accuracy: 0.9977 - val_loss: 0.9675 - val_auc: 0.9124 - val_accuracy: 0.7546
#
# Epoch 00083: val_accuracy did not improve from 0.76931
# Epoch 00083: early stopping
# --------------------------------------------
#
# Results:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:103: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:112: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:121: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.

# %%
#
# load model
#
loaded_model = load_model(filepath=ad_model_filename)

print("Evaluate on test data")
test_results = loaded_model.evaluate(test_dataset, batch_size=NUM_BATCH_SIZE)
print("test loss, test auc test accuracy:", test_results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
test_pred = loaded_model.predict(test_dataset)
test_pred_classes = np.argmax(test_pred, axis=1)

#print ('-----------------------------------------------------')
#print('Confusion Matrix [test DataSet]')
cm = confusion_matrix(test_dataset.classes, test_pred_classes)

print ('-----------------------------------------------------')
print('Classification Report [test DataSet]')
print(classification_report(test_dataset.classes, test_pred_classes, target_names=target_names))

print ('-----------------------------------------------------')
#plot the matrix
f_ad_plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion matrix', cmap=plt.cm.Oranges)
# Out:
# Evaluate on test data
# 10/10 [==============================] - 277s 29s/step - loss: 1.1409 - auc: 0.8870 - accuracy: 0.7514
# test loss, test auc test accuracy: [1.14091157913208, 0.8870028853416443, 0.7513682842254639]
# -----------------------------------------------------
# Classification Report [test DataSet]
#                   precision    recall  f1-score   support
#
#     MildDemented       0.17      0.13      0.15       179
# ModerateDemented       0.00      0.00      0.00        12
#      NonDemented       0.51      0.60      0.55       640
# VeryMildDemented       0.37      0.31      0.33       448
#
#         accuracy                           0.42      1279
#        macro avg       0.26      0.26      0.26      1279
#     weighted avg       0.40      0.42      0.41      1279
#
# -----------------------------------------------------
# Confusion matrix, without normalization
# [[ 23   1 107  48]
#  [  0   0   7   5]
#  [ 68   5 383 184]
#  [ 47   4 260 137]]
