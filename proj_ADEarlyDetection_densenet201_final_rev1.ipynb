# %% [markdown]
# # **Exp 2**
# ### Densenet201
# ### Matrix =auc
# ### acc monitor =val_acc
# ### LR=0.001
# ### CategoricalAccuracy
#
# # **RESULTS**
# ## AUC = 90.58
# ## ACC = 76.34
#   ### Epoch 180/200
#   ### 33/33 [==============================] - 58s 2s/step - loss: 0.2245 - auc: 0.9883 - accuracy: 0.9100 - val_loss: 0.6927 - val_auc: 0.9058 - val_accuracy: 0.7634
#   ### Epoch 00180: val_accuracy improved from 0.74976 to 0.76344, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
#
# # **Question**
#
# ### 1) Confusion Matrix still does not make sense for 76.34 accuracy

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/My Drive/AD_proj"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ADEarlyDetection_densenet201_final.ipynb
# Alzheimer_s_Dataset
# apps_auc_models
# custom_conv_models
# my_best_models
# proj_ADEarlyDetection_densenet201_final_rev0.ipynb
# proj_ADEarlyDetection_densenet201_final_rev1.ipynb

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model, save_model
from keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from keras.metrics import AUC, Accuracy, CategoricalAccuracy
from keras.optimizers import Adam
from keras.applications.densenet import preprocess_input, decode_predictions
from keras.applications.densenet import DenseNet201
from keras.callbacks import EarlyStopping, ModelCheckpoint

import numpy as np
import IPython
import itertools

# Plot libs
from matplotlib import pyplot as plt
import sklearn
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import sys
sys.path.append('/content/drive/My Drive/AD_proj')

#
# Define constants
#
NUM_EPOCH = 200
NUM_PATIENCE = 30
NUM_VAL_SPLIT = 0.2
NUM_IMG_RESCALE = 1/255
NUM_BATCH_SIZE = 128
NUM_IMAGE_SIZE = 224
NUM_LEARNING_RATE = 0.001
ad_model_filepath = "/content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5"

target_names = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
# Data augmentation to avoid overfitting
train = ImageDataGenerator(validation_split=NUM_VAL_SPLIT,
                           rotation_range=40,
                           zoom_range=0.2,
                           horizontal_flip=True, 
                           vertical_flip=True, 
                           rescale=NUM_IMG_RESCALE)

validation = ImageDataGenerator(validation_split=NUM_VAL_SPLIT, rescale=NUM_IMG_RESCALE)

test = ImageDataGenerator(rescale=NUM_IMG_RESCALE)

train_dataset = train.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='training')
val_dataset = validation.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/train', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical', 
    subset='validation')

test_dataset = test.flow_from_directory(
    '/content/drive/My Drive/AD_proj/Alzheimer_s_Dataset/test', 
    target_size=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE), 
    batch_size=NUM_BATCH_SIZE, 
    class_mode='categorical')
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
#--------------------------------------------------------------------
# Function Name: f_ad_model_builder
# Description: Build Convolutional Neural Network (CNN) Deep learning model
#              for early diagnosis of Alzheimer's disease
# Output : 4 output classes 

# Activation function RELU:
# The rectified linear activation function or ReLU for short is a piecewise 
# linear function that will output the input directly if it is positive, 
# otherwise, it will output zero. It has become the default activation function 
# for many types of neural networks because a model that uses it is easier to train 
# and often achieves better performance.
#
#--------------------------------------------------------------------
def f_ad_model_builder():
    
  # 
  # Keras Model Instantiation
  # From https://keras.io/api/applications/: Keras Applications are deep learning models that are 
  # made available alongside pre-trained weights. Weights are downloaded automatically when instantiating a model.
  # It is also known as Transfer layer model
  #model_TL = DenseNet169(input_shape=(NUM_IMAGE_SIZE,NUM_IMAGE_SIZE,3), include_top=False, weights="imagenet")
  model_TL = DenseNet201(input_shape=(NUM_IMAGE_SIZE, NUM_IMAGE_SIZE, 3), include_top=False, weights="imagenet")

  #print('----------- Transfer Layer ---------\n')
  #model_densenet201.summary()
  #print('------------------------------------\n')

  # freeze layers
  for layer in model_TL.layers :
    layer.trainable = False

  # Kera Sequential model is appropriate for deep neural networks
  model = Sequential()
  model.add(model_TL)

  # Dropout is a regularization technique that prevents neural networks from overfitting
  # It modify the network itself. It randomly drops neurons from the neural network 
  # during training in each iteration.
  model.add(Dropout(0.5)) # dropout few nodes to prevent overfitting

  model.add(Flatten()) 

  model.add(BatchNormalization()) # standardize input to next layer

  # Dense later #1
  model.add(Dense(2048,kernel_initializer='he_uniform'))
  
  model.add(BatchNormalization()) # standardize input to next layer 
  model.add(Activation('relu'))
  model.add(Dropout(0.5)) # dropout few nodes to prevent overfitting

  # Dense later #2
  model.add(Dense(1024,kernel_initializer='he_uniform'))

  model.add(BatchNormalization()) # standardize input to next layer
  model.add(Activation('relu'))
  model.add(Dropout(0.5)) # dropout few nodes to prevent overfitting

  # Dense later #3 (Outout)
  model.add(Dense(4,activation='softmax'))

  model.summary()

  #
  # COMPILE: Tune the learning rate for the optimizer value choice 
  # from 0.01, 0.001, or 0.0001
  # 
  model.compile(optimizer = Adam(learning_rate = NUM_LEARNING_RATE),
                loss = 'categorical_crossentropy', 
                metrics = [AUC(name = 'auc', multi_label=True), CategoricalAccuracy(name = 'accuracy')])

  # metrics=['mae', 'acc']
  
  return model

#--------------------------------------------------------------------
# Function Name: f_ad_plot_auc_loss
# Description: 
#              
#--------------------------------------------------------------------
def f_ad_plot_auc_loss(f_model):

  # create subplots
  fig, axs = plt.subplots(nrows=1, ncols=3,figsize=(15,10))

  ticks = np.arange(1,len(f_model.history['loss'])+1)
  history_acc_length = len(f_model.history['accuracy'])+1
  history_val_acc_length = len(f_model.history['val_accuracy'])+1
  history_auc_length = len(f_model.history['auc'])+1
  history_val_auc_length = len(f_model.history['val_auc'])+1
  history_loss_length = len(f_model.history['loss'])+1
  history_val_loss_length = len(f_model.history['val_loss'])+1

  # Summarize history for ACC
  axs[0].plot(range(1,history_acc_length), f_model.history['accuracy'])
  axs[0].plot(range(1,history_val_acc_length), f_model.history['val_accuracy'])
  axs[0].set_title('MODEL ACCURACY')
  axs[0].set_ylabel('ACC')
  axs[0].set_xlabel('Epoch')
  axs[0].set_xticks(ticks,len(f_model.history['accuracy'])/10)
  axs[0].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

  # Summarize history for AUC
  axs[1].plot(range(1,history_auc_length), f_model.history['auc'])
  axs[1].plot(range(1,history_val_auc_length), f_model.history['val_auc'])
  axs[1].set_title('Model Area Under Curve - AUC')
  axs[1].set_ylabel('AUC')
  axs[1].set_xlabel('Epoch')
  axs[1].set_xticks(ticks,len(f_model.history['auc'])/10)
  axs[1].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

  # Summarize history for loss
  axs[2].plot(range(1, history_loss_length), f_model.history['loss'])
  axs[2].plot(range(1,history_val_loss_length), f_model.history['val_loss'])
  axs[2].set_title('Model Loss')
  axs[2].set_ylabel('Loss')
  axs[2].set_xlabel('Epoch')
  axs[2].set_xticks(ticks,len(f_model.history['loss'])/10)
  axs[2].legend(['train', 'val'], loc='best', bbox_to_anchor=(1,1))

#--------------------------------------------------------------------
# Function Name: plot_confusion_matrix
# Description: 
# source code from : scikit-learn.org
#--------------------------------------------------------------------
def f_ad_plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=90)
  plt.yticks(tick_marks, classes)

  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  print(cm)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')

# %%
checkpoint = ModelCheckpoint(ad_model_filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=NUM_PATIENCE, verbose=1, mode='max') 

model = f_ad_model_builder()
model_history = model.fit(train_dataset,
                        validation_data = val_dataset,
                        epochs = NUM_EPOCH,
                        callbacks = [checkpoint, early])

print('--------------------------------------------\n')
print('Results:')
f_ad_plot_auc_loss(model_history)

#!ls -al '/content/drive/My Drive/AD_proj/my_best_models'
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Functional)     (None, 7, 7, 1920)        18321984
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1920)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 94080)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 94080)             376320
# _________________________________________________________________
# dense (Dense)                (None, 2048)              192677888
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 213,490,756
# Trainable params: 194,974,468
# Non-trainable params: 18,516,288
# _________________________________________________________________
# Epoch 1/200
# 33/33 [==============================] - 78s 2s/step - loss: 1.5500 - auc: 0.6365 - accuracy: 0.4651 - val_loss: 2.5631 - val_auc: 0.5307 - val_accuracy: 0.4389
#
# Epoch 00001: val_accuracy improved from -inf to 0.43891, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 2/200
# 33/33 [==============================] - 76s 2s/step - loss: 1.0866 - auc: 0.7165 - accuracy: 0.5747 - val_loss: 2.0136 - val_auc: 0.5440 - val_accuracy: 0.4184
#
# Epoch 00002: val_accuracy did not improve from 0.43891
# Epoch 3/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.9852 - auc: 0.7755 - accuracy: 0.5966 - val_loss: 1.7191 - val_auc: 0.5850 - val_accuracy: 0.3969
#
# Epoch 00003: val_accuracy did not improve from 0.43891
# Epoch 4/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.9616 - auc: 0.7788 - accuracy: 0.5897 - val_loss: 1.2409 - val_auc: 0.6361 - val_accuracy: 0.4751
#
# Epoch 00004: val_accuracy improved from 0.43891 to 0.47507, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 5/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.9144 - auc: 0.7938 - accuracy: 0.6101 - val_loss: 1.2441 - val_auc: 0.6153 - val_accuracy: 0.4438
#
# Epoch 00005: val_accuracy did not improve from 0.47507
# Epoch 6/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.8601 - auc: 0.8292 - accuracy: 0.6329 - val_loss: 1.1709 - val_auc: 0.6574 - val_accuracy: 0.4633
#
# Epoch 00006: val_accuracy did not improve from 0.47507
# Epoch 7/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.8341 - auc: 0.8213 - accuracy: 0.6233 - val_loss: 1.1886 - val_auc: 0.7411 - val_accuracy: 0.5386
#
# Epoch 00007: val_accuracy improved from 0.47507 to 0.53861, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 8/200
# 33/33 [==============================] - 77s 2s/step - loss: 0.8027 - auc: 0.8385 - accuracy: 0.6457 - val_loss: 1.2742 - val_auc: 0.7155 - val_accuracy: 0.5015
#
# Epoch 00008: val_accuracy did not improve from 0.53861
# Epoch 9/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.7625 - auc: 0.8527 - accuracy: 0.6807 - val_loss: 1.1580 - val_auc: 0.7505 - val_accuracy: 0.5308
#
# Epoch 00009: val_accuracy did not improve from 0.53861
# Epoch 10/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.7617 - auc: 0.8615 - accuracy: 0.6654 - val_loss: 1.0421 - val_auc: 0.7707 - val_accuracy: 0.5601
#
# Epoch 00010: val_accuracy improved from 0.53861 to 0.56012, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 11/200
# 33/33 [==============================] - 75s 2s/step - loss: 0.7511 - auc: 0.8680 - accuracy: 0.6778 - val_loss: 1.0737 - val_auc: 0.7568 - val_accuracy: 0.5308
#
# Epoch 00011: val_accuracy did not improve from 0.56012
# Epoch 12/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.7564 - auc: 0.8587 - accuracy: 0.6671 - val_loss: 1.0578 - val_auc: 0.7447 - val_accuracy: 0.5308
#
# Epoch 00012: val_accuracy did not improve from 0.56012
# Epoch 13/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.7190 - auc: 0.8735 - accuracy: 0.6890 - val_loss: 1.2605 - val_auc: 0.7124 - val_accuracy: 0.4604
#
# Epoch 00013: val_accuracy did not improve from 0.56012
# Epoch 14/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.7102 - auc: 0.8732 - accuracy: 0.6965 - val_loss: 1.1041 - val_auc: 0.7614 - val_accuracy: 0.5308
#
# Epoch 00014: val_accuracy did not improve from 0.56012
# Epoch 15/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6763 - auc: 0.8764 - accuracy: 0.7109 - val_loss: 1.2275 - val_auc: 0.7325 - val_accuracy: 0.4516
#
# Epoch 00015: val_accuracy did not improve from 0.56012
# Epoch 16/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6845 - auc: 0.8918 - accuracy: 0.7000 - val_loss: 1.0951 - val_auc: 0.7894 - val_accuracy: 0.5308
#
# Epoch 00016: val_accuracy did not improve from 0.56012
# Epoch 17/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6701 - auc: 0.8875 - accuracy: 0.7047 - val_loss: 1.0533 - val_auc: 0.7835 - val_accuracy: 0.5415
#
# Epoch 00017: val_accuracy did not improve from 0.56012
# Epoch 18/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6409 - auc: 0.9053 - accuracy: 0.7201 - val_loss: 1.2111 - val_auc: 0.7603 - val_accuracy: 0.5103
#
# Epoch 00018: val_accuracy did not improve from 0.56012
# Epoch 19/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6205 - auc: 0.9140 - accuracy: 0.7418 - val_loss: 1.2069 - val_auc: 0.7575 - val_accuracy: 0.5103
#
# Epoch 00019: val_accuracy did not improve from 0.56012
# Epoch 20/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6250 - auc: 0.8979 - accuracy: 0.7280 - val_loss: 1.2244 - val_auc: 0.7791 - val_accuracy: 0.5464
#
# Epoch 00020: val_accuracy did not improve from 0.56012
# Epoch 21/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6069 - auc: 0.9048 - accuracy: 0.7395 - val_loss: 1.2790 - val_auc: 0.7705 - val_accuracy: 0.5054
#
# Epoch 00021: val_accuracy did not improve from 0.56012
# Epoch 22/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6247 - auc: 0.9120 - accuracy: 0.7297 - val_loss: 1.2152 - val_auc: 0.8001 - val_accuracy: 0.5533
#
# Epoch 00022: val_accuracy did not improve from 0.56012
# Epoch 23/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5821 - auc: 0.9227 - accuracy: 0.7510 - val_loss: 1.0461 - val_auc: 0.8040 - val_accuracy: 0.5582
#
# Epoch 00023: val_accuracy did not improve from 0.56012
# Epoch 24/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.6098 - auc: 0.9150 - accuracy: 0.7361 - val_loss: 1.1753 - val_auc: 0.7631 - val_accuracy: 0.5181
#
# Epoch 00024: val_accuracy did not improve from 0.56012
# Epoch 25/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5855 - auc: 0.9058 - accuracy: 0.7378 - val_loss: 1.1629 - val_auc: 0.7908 - val_accuracy: 0.5298
#
# Epoch 00025: val_accuracy did not improve from 0.56012
# Epoch 26/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5836 - auc: 0.9199 - accuracy: 0.7503 - val_loss: 1.0007 - val_auc: 0.8151 - val_accuracy: 0.5621
#
# Epoch 00026: val_accuracy improved from 0.56012 to 0.56207, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 27/200
# 33/33 [==============================] - 73s 2s/step - loss: 0.5677 - auc: 0.9232 - accuracy: 0.7618 - val_loss: 1.2386 - val_auc: 0.7635 - val_accuracy: 0.5279
#
# Epoch 00027: val_accuracy did not improve from 0.56207
# Epoch 28/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5715 - auc: 0.9231 - accuracy: 0.7548 - val_loss: 1.2028 - val_auc: 0.7844 - val_accuracy: 0.5494
#
# Epoch 00028: val_accuracy did not improve from 0.56207
# Epoch 29/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5522 - auc: 0.9306 - accuracy: 0.7617 - val_loss: 1.0990 - val_auc: 0.8030 - val_accuracy: 0.5640
#
# Epoch 00029: val_accuracy improved from 0.56207 to 0.56403, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 30/200
# 33/33 [==============================] - 74s 2s/step - loss: 0.5352 - auc: 0.9329 - accuracy: 0.7653 - val_loss: 1.2783 - val_auc: 0.7916 - val_accuracy: 0.5679
#
# Epoch 00030: val_accuracy improved from 0.56403 to 0.56794, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 31/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.5426 - auc: 0.9325 - accuracy: 0.7772 - val_loss: 1.1397 - val_auc: 0.7956 - val_accuracy: 0.5767
#
# Epoch 00031: val_accuracy improved from 0.56794 to 0.57674, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 32/200
# 33/33 [==============================] - 73s 2s/step - loss: 0.5415 - auc: 0.9312 - accuracy: 0.7691 - val_loss: 1.3558 - val_auc: 0.7481 - val_accuracy: 0.5435
#
# Epoch 00032: val_accuracy did not improve from 0.57674
# Epoch 33/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5593 - auc: 0.9212 - accuracy: 0.7649 - val_loss: 1.2990 - val_auc: 0.7698 - val_accuracy: 0.5621
#
# Epoch 00033: val_accuracy did not improve from 0.57674
# Epoch 34/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5479 - auc: 0.9258 - accuracy: 0.7647 - val_loss: 1.1945 - val_auc: 0.7860 - val_accuracy: 0.5670
#
# Epoch 00034: val_accuracy did not improve from 0.57674
# Epoch 35/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5492 - auc: 0.9325 - accuracy: 0.7661 - val_loss: 1.2540 - val_auc: 0.7759 - val_accuracy: 0.5318
#
# Epoch 00035: val_accuracy did not improve from 0.57674
# Epoch 36/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5466 - auc: 0.9139 - accuracy: 0.7615 - val_loss: 1.1079 - val_auc: 0.8247 - val_accuracy: 0.5963
#
# Epoch 00036: val_accuracy improved from 0.57674 to 0.59629, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 37/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.5133 - auc: 0.9256 - accuracy: 0.7807 - val_loss: 1.3469 - val_auc: 0.7914 - val_accuracy: 0.5748
#
# Epoch 00037: val_accuracy did not improve from 0.59629
# Epoch 38/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5437 - auc: 0.9214 - accuracy: 0.7679 - val_loss: 1.0492 - val_auc: 0.8272 - val_accuracy: 0.5875
#
# Epoch 00038: val_accuracy did not improve from 0.59629
# Epoch 39/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5205 - auc: 0.9324 - accuracy: 0.7837 - val_loss: 1.1811 - val_auc: 0.8143 - val_accuracy: 0.5738
#
# Epoch 00039: val_accuracy did not improve from 0.59629
# Epoch 40/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5121 - auc: 0.9393 - accuracy: 0.7779 - val_loss: 1.1613 - val_auc: 0.8077 - val_accuracy: 0.5787
#
# Epoch 00040: val_accuracy did not improve from 0.59629
# Epoch 41/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5170 - auc: 0.9373 - accuracy: 0.7726 - val_loss: 1.0814 - val_auc: 0.8127 - val_accuracy: 0.5875
#
# Epoch 00041: val_accuracy did not improve from 0.59629
# Epoch 42/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5154 - auc: 0.9385 - accuracy: 0.7780 - val_loss: 1.2119 - val_auc: 0.7826 - val_accuracy: 0.5543
#
# Epoch 00042: val_accuracy did not improve from 0.59629
# Epoch 43/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4636 - auc: 0.9501 - accuracy: 0.7985 - val_loss: 1.2230 - val_auc: 0.7878 - val_accuracy: 0.5630
#
# Epoch 00043: val_accuracy did not improve from 0.59629
# Epoch 44/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4815 - auc: 0.9453 - accuracy: 0.7906 - val_loss: 1.3142 - val_auc: 0.7914 - val_accuracy: 0.5728
#
# Epoch 00044: val_accuracy did not improve from 0.59629
# Epoch 45/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4793 - auc: 0.9337 - accuracy: 0.8024 - val_loss: 1.2487 - val_auc: 0.8178 - val_accuracy: 0.5718
#
# Epoch 00045: val_accuracy did not improve from 0.59629
# Epoch 46/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4694 - auc: 0.9423 - accuracy: 0.8018 - val_loss: 1.0739 - val_auc: 0.8227 - val_accuracy: 0.6022
#
# Epoch 00046: val_accuracy improved from 0.59629 to 0.60215, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 47/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.4698 - auc: 0.9490 - accuracy: 0.8128 - val_loss: 1.1641 - val_auc: 0.8218 - val_accuracy: 0.5855
#
# Epoch 00047: val_accuracy did not improve from 0.60215
# Epoch 48/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.5084 - auc: 0.9389 - accuracy: 0.7924 - val_loss: 1.0360 - val_auc: 0.8299 - val_accuracy: 0.6256
#
# Epoch 00048: val_accuracy improved from 0.60215 to 0.62561, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 49/200
# 33/33 [==============================] - 73s 2s/step - loss: 0.4517 - auc: 0.9466 - accuracy: 0.8124 - val_loss: 1.2961 - val_auc: 0.8233 - val_accuracy: 0.6109
#
# Epoch 00049: val_accuracy did not improve from 0.62561
# Epoch 50/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4645 - auc: 0.9513 - accuracy: 0.8078 - val_loss: 1.2243 - val_auc: 0.7894 - val_accuracy: 0.5630
#
# Epoch 00050: val_accuracy did not improve from 0.62561
# Epoch 51/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4706 - auc: 0.9464 - accuracy: 0.8019 - val_loss: 1.0449 - val_auc: 0.8093 - val_accuracy: 0.5875
#
# Epoch 00051: val_accuracy did not improve from 0.62561
# Epoch 52/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4878 - auc: 0.9464 - accuracy: 0.7903 - val_loss: 1.0434 - val_auc: 0.8250 - val_accuracy: 0.5816
#
# Epoch 00052: val_accuracy did not improve from 0.62561
# Epoch 53/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4357 - auc: 0.9407 - accuracy: 0.8251 - val_loss: 1.1910 - val_auc: 0.8234 - val_accuracy: 0.6002
#
# Epoch 00053: val_accuracy did not improve from 0.62561
# Epoch 54/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4286 - auc: 0.9578 - accuracy: 0.8244 - val_loss: 0.9448 - val_auc: 0.8429 - val_accuracy: 0.6266
#
# Epoch 00054: val_accuracy improved from 0.62561 to 0.62659, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 55/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.4624 - auc: 0.9525 - accuracy: 0.8038 - val_loss: 1.1938 - val_auc: 0.8185 - val_accuracy: 0.5992
#
# Epoch 00055: val_accuracy did not improve from 0.62659
# Epoch 56/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4386 - auc: 0.9540 - accuracy: 0.8206 - val_loss: 1.0118 - val_auc: 0.8281 - val_accuracy: 0.6158
#
# Epoch 00056: val_accuracy did not improve from 0.62659
# Epoch 57/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4623 - auc: 0.9499 - accuracy: 0.8062 - val_loss: 1.1359 - val_auc: 0.8092 - val_accuracy: 0.5826
#
# Epoch 00057: val_accuracy did not improve from 0.62659
# Epoch 58/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4242 - auc: 0.9576 - accuracy: 0.8286 - val_loss: 1.1073 - val_auc: 0.8191 - val_accuracy: 0.6022
#
# Epoch 00058: val_accuracy did not improve from 0.62659
# Epoch 59/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4563 - auc: 0.9517 - accuracy: 0.8181 - val_loss: 0.9686 - val_auc: 0.8518 - val_accuracy: 0.6197
#
# Epoch 00059: val_accuracy did not improve from 0.62659
# Epoch 60/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4530 - auc: 0.9446 - accuracy: 0.8060 - val_loss: 1.0585 - val_auc: 0.8334 - val_accuracy: 0.6109
#
# Epoch 00060: val_accuracy did not improve from 0.62659
# Epoch 61/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3984 - auc: 0.9607 - accuracy: 0.8412 - val_loss: 1.2367 - val_auc: 0.8131 - val_accuracy: 0.5963
#
# Epoch 00061: val_accuracy did not improve from 0.62659
# Epoch 62/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4403 - auc: 0.9566 - accuracy: 0.8155 - val_loss: 1.0232 - val_auc: 0.8408 - val_accuracy: 0.6022
#
# Epoch 00062: val_accuracy did not improve from 0.62659
# Epoch 63/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4101 - auc: 0.9617 - accuracy: 0.8333 - val_loss: 0.9830 - val_auc: 0.8417 - val_accuracy: 0.5982
#
# Epoch 00063: val_accuracy did not improve from 0.62659
# Epoch 64/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4321 - auc: 0.9559 - accuracy: 0.8277 - val_loss: 1.3223 - val_auc: 0.8012 - val_accuracy: 0.5865
#
# Epoch 00064: val_accuracy did not improve from 0.62659
# Epoch 65/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4459 - auc: 0.9546 - accuracy: 0.8138 - val_loss: 1.1059 - val_auc: 0.8083 - val_accuracy: 0.5934
#
# Epoch 00065: val_accuracy did not improve from 0.62659
# Epoch 66/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4175 - auc: 0.9527 - accuracy: 0.8234 - val_loss: 1.1531 - val_auc: 0.8236 - val_accuracy: 0.6119
#
# Epoch 00066: val_accuracy did not improve from 0.62659
# Epoch 67/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3911 - auc: 0.9490 - accuracy: 0.8342 - val_loss: 1.2690 - val_auc: 0.7996 - val_accuracy: 0.5855
#
# Epoch 00067: val_accuracy did not improve from 0.62659
# Epoch 68/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4253 - auc: 0.9588 - accuracy: 0.8268 - val_loss: 1.1554 - val_auc: 0.8299 - val_accuracy: 0.5973
#
# Epoch 00068: val_accuracy did not improve from 0.62659
# Epoch 69/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3914 - auc: 0.9639 - accuracy: 0.8410 - val_loss: 1.1484 - val_auc: 0.8423 - val_accuracy: 0.6295
#
# Epoch 00069: val_accuracy improved from 0.62659 to 0.62952, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 70/200
# 33/33 [==============================] - 74s 2s/step - loss: 0.4265 - auc: 0.9506 - accuracy: 0.8294 - val_loss: 1.3023 - val_auc: 0.8188 - val_accuracy: 0.5846
#
# Epoch 00070: val_accuracy did not improve from 0.62952
# Epoch 71/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4044 - auc: 0.9628 - accuracy: 0.8274 - val_loss: 1.1845 - val_auc: 0.8342 - val_accuracy: 0.6119
#
# Epoch 00071: val_accuracy did not improve from 0.62952
# Epoch 72/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3678 - auc: 0.9685 - accuracy: 0.8441 - val_loss: 1.2876 - val_auc: 0.8261 - val_accuracy: 0.5885
#
# Epoch 00072: val_accuracy did not improve from 0.62952
# Epoch 73/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3964 - auc: 0.9645 - accuracy: 0.8321 - val_loss: 1.0819 - val_auc: 0.8284 - val_accuracy: 0.6139
#
# Epoch 00073: val_accuracy did not improve from 0.62952
# Epoch 74/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3695 - auc: 0.9681 - accuracy: 0.8406 - val_loss: 1.1262 - val_auc: 0.8254 - val_accuracy: 0.6012
#
# Epoch 00074: val_accuracy did not improve from 0.62952
# Epoch 75/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3761 - auc: 0.9624 - accuracy: 0.8432 - val_loss: 1.3994 - val_auc: 0.8056 - val_accuracy: 0.5826
#
# Epoch 00075: val_accuracy did not improve from 0.62952
# Epoch 76/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.4143 - auc: 0.9622 - accuracy: 0.8317 - val_loss: 1.2762 - val_auc: 0.8242 - val_accuracy: 0.5758
#
# Epoch 00076: val_accuracy did not improve from 0.62952
# Epoch 77/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3761 - auc: 0.9663 - accuracy: 0.8456 - val_loss: 1.0371 - val_auc: 0.8377 - val_accuracy: 0.6237
#
# Epoch 00077: val_accuracy did not improve from 0.62952
# Epoch 78/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3932 - auc: 0.9657 - accuracy: 0.8383 - val_loss: 1.3209 - val_auc: 0.8227 - val_accuracy: 0.6119
#
# Epoch 00078: val_accuracy did not improve from 0.62952
# Epoch 79/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3800 - auc: 0.9662 - accuracy: 0.8418 - val_loss: 1.2944 - val_auc: 0.8111 - val_accuracy: 0.5865
#
# Epoch 00079: val_accuracy did not improve from 0.62952
# Epoch 80/200
# 33/33 [==============================] - 55s 2s/step - loss: 0.3687 - auc: 0.9679 - accuracy: 0.8443 - val_loss: 1.3620 - val_auc: 0.8048 - val_accuracy: 0.5875
#
# Epoch 00080: val_accuracy did not improve from 0.62952
# Epoch 81/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3626 - auc: 0.9692 - accuracy: 0.8607 - val_loss: 1.2248 - val_auc: 0.8367 - val_accuracy: 0.6178
#
# Epoch 00081: val_accuracy did not improve from 0.62952
# Epoch 82/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3626 - auc: 0.9522 - accuracy: 0.8503 - val_loss: 1.2821 - val_auc: 0.8163 - val_accuracy: 0.6070
#
# Epoch 00082: val_accuracy did not improve from 0.62952
# Epoch 83/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3745 - auc: 0.9686 - accuracy: 0.8501 - val_loss: 1.3113 - val_auc: 0.8042 - val_accuracy: 0.5953
#
# Epoch 00083: val_accuracy did not improve from 0.62952
# Epoch 84/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3607 - auc: 0.9624 - accuracy: 0.8500 - val_loss: 1.1915 - val_auc: 0.8168 - val_accuracy: 0.5973
#
# Epoch 00084: val_accuracy did not improve from 0.62952
# Epoch 85/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3872 - auc: 0.9654 - accuracy: 0.8415 - val_loss: 1.3520 - val_auc: 0.8243 - val_accuracy: 0.6070
#
# Epoch 00085: val_accuracy did not improve from 0.62952
# Epoch 86/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3573 - auc: 0.9705 - accuracy: 0.8582 - val_loss: 1.2984 - val_auc: 0.8267 - val_accuracy: 0.6188
#
# Epoch 00086: val_accuracy did not improve from 0.62952
# Epoch 87/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3769 - auc: 0.9669 - accuracy: 0.8472 - val_loss: 1.0556 - val_auc: 0.8520 - val_accuracy: 0.6452
#
# Epoch 00087: val_accuracy improved from 0.62952 to 0.64516, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 88/200
# 33/33 [==============================] - 77s 2s/step - loss: 0.3620 - auc: 0.9690 - accuracy: 0.8556 - val_loss: 1.2837 - val_auc: 0.8263 - val_accuracy: 0.6188
#
# Epoch 00088: val_accuracy did not improve from 0.64516
# Epoch 89/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3503 - auc: 0.9492 - accuracy: 0.8581 - val_loss: 0.9065 - val_auc: 0.8580 - val_accuracy: 0.6676
#
# Epoch 00089: val_accuracy improved from 0.64516 to 0.66764, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 90/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.3932 - auc: 0.9677 - accuracy: 0.8417 - val_loss: 1.1304 - val_auc: 0.8318 - val_accuracy: 0.6266
#
# Epoch 00090: val_accuracy did not improve from 0.66764
# Epoch 91/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3810 - auc: 0.9516 - accuracy: 0.8411 - val_loss: 1.1549 - val_auc: 0.8312 - val_accuracy: 0.6383
#
# Epoch 00091: val_accuracy did not improve from 0.66764
# Epoch 92/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3352 - auc: 0.9735 - accuracy: 0.8720 - val_loss: 1.0828 - val_auc: 0.8511 - val_accuracy: 0.6285
#
# Epoch 00092: val_accuracy did not improve from 0.66764
# Epoch 93/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3929 - auc: 0.9594 - accuracy: 0.8439 - val_loss: 1.2325 - val_auc: 0.8450 - val_accuracy: 0.6100
#
# Epoch 00093: val_accuracy did not improve from 0.66764
# Epoch 94/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3746 - auc: 0.9704 - accuracy: 0.8507 - val_loss: 1.0825 - val_auc: 0.8702 - val_accuracy: 0.6588
#
# Epoch 00094: val_accuracy did not improve from 0.66764
# Epoch 95/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3684 - auc: 0.9688 - accuracy: 0.8542 - val_loss: 0.9273 - val_auc: 0.8555 - val_accuracy: 0.6559
#
# Epoch 00095: val_accuracy did not improve from 0.66764
# Epoch 96/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.4119 - auc: 0.9667 - accuracy: 0.8383 - val_loss: 0.9057 - val_auc: 0.8808 - val_accuracy: 0.6569
#
# Epoch 00096: val_accuracy did not improve from 0.66764
# Epoch 97/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.4799 - auc: 0.9372 - accuracy: 0.8221 - val_loss: 1.0974 - val_auc: 0.8675 - val_accuracy: 0.6461
#
# Epoch 00097: val_accuracy did not improve from 0.66764
# Epoch 98/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3677 - auc: 0.9685 - accuracy: 0.8472 - val_loss: 1.2397 - val_auc: 0.8725 - val_accuracy: 0.6618
#
# Epoch 00098: val_accuracy did not improve from 0.66764
# Epoch 99/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3392 - auc: 0.9734 - accuracy: 0.8701 - val_loss: 0.8577 - val_auc: 0.8698 - val_accuracy: 0.6833
#
# Epoch 00099: val_accuracy improved from 0.66764 to 0.68328, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 100/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.3495 - auc: 0.9556 - accuracy: 0.8607 - val_loss: 0.9775 - val_auc: 0.8448 - val_accuracy: 0.6579
#
# Epoch 00100: val_accuracy did not improve from 0.68328
# Epoch 101/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3611 - auc: 0.9644 - accuracy: 0.8446 - val_loss: 1.2515 - val_auc: 0.8488 - val_accuracy: 0.6442
#
# Epoch 00101: val_accuracy did not improve from 0.68328
# Epoch 102/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3225 - auc: 0.9675 - accuracy: 0.8749 - val_loss: 1.2148 - val_auc: 0.8591 - val_accuracy: 0.6559
#
# Epoch 00102: val_accuracy did not improve from 0.68328
# Epoch 103/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3478 - auc: 0.9652 - accuracy: 0.8649 - val_loss: 0.9663 - val_auc: 0.8748 - val_accuracy: 0.6618
#
# Epoch 00103: val_accuracy did not improve from 0.68328
# Epoch 104/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3129 - auc: 0.9766 - accuracy: 0.8665 - val_loss: 0.9527 - val_auc: 0.8684 - val_accuracy: 0.6618
#
# Epoch 00104: val_accuracy did not improve from 0.68328
# Epoch 105/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3586 - auc: 0.9731 - accuracy: 0.8543 - val_loss: 1.1805 - val_auc: 0.8545 - val_accuracy: 0.6549
#
# Epoch 00105: val_accuracy did not improve from 0.68328
# Epoch 106/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3240 - auc: 0.9751 - accuracy: 0.8667 - val_loss: 1.4016 - val_auc: 0.8192 - val_accuracy: 0.6354
#
# Epoch 00106: val_accuracy did not improve from 0.68328
# Epoch 107/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3341 - auc: 0.9664 - accuracy: 0.8629 - val_loss: 1.3300 - val_auc: 0.8125 - val_accuracy: 0.6246
#
# Epoch 00107: val_accuracy did not improve from 0.68328
# Epoch 108/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3207 - auc: 0.9610 - accuracy: 0.8706 - val_loss: 1.0401 - val_auc: 0.8629 - val_accuracy: 0.6676
#
# Epoch 00108: val_accuracy did not improve from 0.68328
# Epoch 109/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2987 - auc: 0.9717 - accuracy: 0.8788 - val_loss: 1.2085 - val_auc: 0.8329 - val_accuracy: 0.6354
#
# Epoch 00109: val_accuracy did not improve from 0.68328
# Epoch 110/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3314 - auc: 0.9753 - accuracy: 0.8658 - val_loss: 1.0744 - val_auc: 0.8720 - val_accuracy: 0.6804
#
# Epoch 00110: val_accuracy did not improve from 0.68328
# Epoch 111/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3169 - auc: 0.9766 - accuracy: 0.8764 - val_loss: 1.1314 - val_auc: 0.8520 - val_accuracy: 0.6696
#
# Epoch 00111: val_accuracy did not improve from 0.68328
# Epoch 112/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3491 - auc: 0.9721 - accuracy: 0.8631 - val_loss: 1.1329 - val_auc: 0.8499 - val_accuracy: 0.6716
#
# Epoch 00112: val_accuracy did not improve from 0.68328
# Epoch 113/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2992 - auc: 0.9635 - accuracy: 0.8848 - val_loss: 1.0946 - val_auc: 0.8538 - val_accuracy: 0.6647
#
# Epoch 00113: val_accuracy did not improve from 0.68328
# Epoch 114/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3154 - auc: 0.9765 - accuracy: 0.8654 - val_loss: 1.1215 - val_auc: 0.8628 - val_accuracy: 0.6540
#
# Epoch 00114: val_accuracy did not improve from 0.68328
# Epoch 115/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3664 - auc: 0.9714 - accuracy: 0.8607 - val_loss: 1.0822 - val_auc: 0.8648 - val_accuracy: 0.6628
#
# Epoch 00115: val_accuracy did not improve from 0.68328
# Epoch 116/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2951 - auc: 0.9797 - accuracy: 0.8801 - val_loss: 1.1330 - val_auc: 0.8687 - val_accuracy: 0.6559
#
# Epoch 00116: val_accuracy did not improve from 0.68328
# Epoch 117/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3578 - auc: 0.9724 - accuracy: 0.8560 - val_loss: 1.2061 - val_auc: 0.8630 - val_accuracy: 0.6432
#
# Epoch 00117: val_accuracy did not improve from 0.68328
# Epoch 118/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3534 - auc: 0.9711 - accuracy: 0.8569 - val_loss: 1.2256 - val_auc: 0.8550 - val_accuracy: 0.6481
#
# Epoch 00118: val_accuracy did not improve from 0.68328
# Epoch 119/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3313 - auc: 0.9737 - accuracy: 0.8541 - val_loss: 1.2670 - val_auc: 0.8611 - val_accuracy: 0.6510
#
# Epoch 00119: val_accuracy did not improve from 0.68328
# Epoch 120/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2726 - auc: 0.9825 - accuracy: 0.8907 - val_loss: 0.9843 - val_auc: 0.8787 - val_accuracy: 0.6725
#
# Epoch 00120: val_accuracy did not improve from 0.68328
# Epoch 121/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3104 - auc: 0.9699 - accuracy: 0.8780 - val_loss: 1.2477 - val_auc: 0.8472 - val_accuracy: 0.6579
#
# Epoch 00121: val_accuracy did not improve from 0.68328
# Epoch 122/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2684 - auc: 0.9824 - accuracy: 0.8886 - val_loss: 1.0647 - val_auc: 0.8757 - val_accuracy: 0.6774
#
# Epoch 00122: val_accuracy did not improve from 0.68328
# Epoch 123/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2773 - auc: 0.9641 - accuracy: 0.8906 - val_loss: 1.0744 - val_auc: 0.8656 - val_accuracy: 0.6637
#
# Epoch 00123: val_accuracy did not improve from 0.68328
# Epoch 124/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2909 - auc: 0.9799 - accuracy: 0.8867 - val_loss: 0.9338 - val_auc: 0.8693 - val_accuracy: 0.6813
#
# Epoch 00124: val_accuracy did not improve from 0.68328
# Epoch 125/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3160 - auc: 0.9688 - accuracy: 0.8760 - val_loss: 1.0446 - val_auc: 0.8677 - val_accuracy: 0.6637
#
# Epoch 00125: val_accuracy did not improve from 0.68328
# Epoch 126/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2907 - auc: 0.9807 - accuracy: 0.8814 - val_loss: 1.0334 - val_auc: 0.8701 - val_accuracy: 0.6784
#
# Epoch 00126: val_accuracy did not improve from 0.68328
# Epoch 127/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2895 - auc: 0.9805 - accuracy: 0.8824 - val_loss: 0.9513 - val_auc: 0.8758 - val_accuracy: 0.6716
#
# Epoch 00127: val_accuracy did not improve from 0.68328
# Epoch 128/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2815 - auc: 0.9819 - accuracy: 0.8898 - val_loss: 0.9899 - val_auc: 0.8681 - val_accuracy: 0.6686
#
# Epoch 00128: val_accuracy did not improve from 0.68328
# Epoch 129/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2799 - auc: 0.9807 - accuracy: 0.8823 - val_loss: 0.9196 - val_auc: 0.8878 - val_accuracy: 0.6960
#
# Epoch 00129: val_accuracy improved from 0.68328 to 0.69599, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 130/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.2655 - auc: 0.9835 - accuracy: 0.8863 - val_loss: 0.9496 - val_auc: 0.8875 - val_accuracy: 0.6882
#
# Epoch 00130: val_accuracy did not improve from 0.69599
# Epoch 131/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2801 - auc: 0.9819 - accuracy: 0.8874 - val_loss: 1.1153 - val_auc: 0.8712 - val_accuracy: 0.6676
#
# Epoch 00131: val_accuracy did not improve from 0.69599
# Epoch 132/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2692 - auc: 0.9831 - accuracy: 0.8952 - val_loss: 1.1237 - val_auc: 0.8775 - val_accuracy: 0.6696
#
# Epoch 00132: val_accuracy did not improve from 0.69599
# Epoch 133/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.3095 - auc: 0.9776 - accuracy: 0.8770 - val_loss: 0.9363 - val_auc: 0.8820 - val_accuracy: 0.6970
#
# Epoch 00133: val_accuracy improved from 0.69599 to 0.69697, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 134/200
# 33/33 [==============================] - 77s 2s/step - loss: 0.3000 - auc: 0.9798 - accuracy: 0.8785 - val_loss: 1.1425 - val_auc: 0.8683 - val_accuracy: 0.6657
#
# Epoch 00134: val_accuracy did not improve from 0.69697
# Epoch 135/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2860 - auc: 0.9803 - accuracy: 0.8843 - val_loss: 1.0873 - val_auc: 0.8794 - val_accuracy: 0.6833
#
# Epoch 00135: val_accuracy did not improve from 0.69697
# Epoch 136/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2931 - auc: 0.9806 - accuracy: 0.8867 - val_loss: 1.2367 - val_auc: 0.8528 - val_accuracy: 0.6491
#
# Epoch 00136: val_accuracy did not improve from 0.69697
# Epoch 137/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2762 - auc: 0.9820 - accuracy: 0.8895 - val_loss: 1.1265 - val_auc: 0.8684 - val_accuracy: 0.6891
#
# Epoch 00137: val_accuracy did not improve from 0.69697
# Epoch 138/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3022 - auc: 0.9659 - accuracy: 0.8803 - val_loss: 0.9347 - val_auc: 0.8709 - val_accuracy: 0.7038
#
# Epoch 00138: val_accuracy improved from 0.69697 to 0.70381, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 139/200
# 33/33 [==============================] - 76s 2s/step - loss: 0.2869 - auc: 0.9667 - accuracy: 0.8871 - val_loss: 0.9845 - val_auc: 0.8720 - val_accuracy: 0.6940
#
# Epoch 00139: val_accuracy did not improve from 0.70381
# Epoch 140/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2820 - auc: 0.9809 - accuracy: 0.8925 - val_loss: 1.1705 - val_auc: 0.8667 - val_accuracy: 0.6735
#
# Epoch 00140: val_accuracy did not improve from 0.70381
# Epoch 141/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2575 - auc: 0.9841 - accuracy: 0.8977 - val_loss: 1.3298 - val_auc: 0.8649 - val_accuracy: 0.6618
#
# Epoch 00141: val_accuracy did not improve from 0.70381
# Epoch 142/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2521 - auc: 0.9849 - accuracy: 0.9008 - val_loss: 1.0790 - val_auc: 0.8644 - val_accuracy: 0.6823
#
# Epoch 00142: val_accuracy did not improve from 0.70381
# Epoch 143/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2577 - auc: 0.9835 - accuracy: 0.8936 - val_loss: 1.0410 - val_auc: 0.8855 - val_accuracy: 0.6833
#
# Epoch 00143: val_accuracy did not improve from 0.70381
# Epoch 144/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2719 - auc: 0.9834 - accuracy: 0.8897 - val_loss: 1.0893 - val_auc: 0.8715 - val_accuracy: 0.6794
#
# Epoch 00144: val_accuracy did not improve from 0.70381
# Epoch 145/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.3001 - auc: 0.9783 - accuracy: 0.8771 - val_loss: 1.0326 - val_auc: 0.8708 - val_accuracy: 0.6813
#
# Epoch 00145: val_accuracy did not improve from 0.70381
# Epoch 146/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.3048 - auc: 0.9728 - accuracy: 0.8819 - val_loss: 0.8844 - val_auc: 0.8886 - val_accuracy: 0.7253
#
# Epoch 00146: val_accuracy improved from 0.70381 to 0.72532, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 147/200
# 33/33 [==============================] - 79s 2s/step - loss: 0.2696 - auc: 0.9822 - accuracy: 0.8904 - val_loss: 1.0680 - val_auc: 0.8871 - val_accuracy: 0.6931
#
# Epoch 00147: val_accuracy did not improve from 0.72532
# Epoch 148/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2680 - auc: 0.9830 - accuracy: 0.8962 - val_loss: 0.9093 - val_auc: 0.8893 - val_accuracy: 0.7136
#
# Epoch 00148: val_accuracy did not improve from 0.72532
# Epoch 149/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2528 - auc: 0.9844 - accuracy: 0.8995 - val_loss: 0.8561 - val_auc: 0.8859 - val_accuracy: 0.7204
#
# Epoch 00149: val_accuracy did not improve from 0.72532
# Epoch 150/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2585 - auc: 0.9768 - accuracy: 0.8953 - val_loss: 0.8495 - val_auc: 0.8842 - val_accuracy: 0.7253
#
# Epoch 00150: val_accuracy did not improve from 0.72532
# Epoch 151/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.3023 - auc: 0.9801 - accuracy: 0.8781 - val_loss: 0.9217 - val_auc: 0.8837 - val_accuracy: 0.7067
#
# Epoch 00151: val_accuracy did not improve from 0.72532
# Epoch 152/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2797 - auc: 0.9666 - accuracy: 0.8908 - val_loss: 1.1615 - val_auc: 0.8893 - val_accuracy: 0.6657
#
# Epoch 00152: val_accuracy did not improve from 0.72532
# Epoch 153/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2698 - auc: 0.9835 - accuracy: 0.8984 - val_loss: 0.9012 - val_auc: 0.8876 - val_accuracy: 0.6999
#
# Epoch 00153: val_accuracy did not improve from 0.72532
# Epoch 154/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2627 - auc: 0.9835 - accuracy: 0.8994 - val_loss: 0.9759 - val_auc: 0.8887 - val_accuracy: 0.6862
#
# Epoch 00154: val_accuracy did not improve from 0.72532
# Epoch 155/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2789 - auc: 0.9825 - accuracy: 0.8907 - val_loss: 0.8824 - val_auc: 0.8896 - val_accuracy: 0.6989
#
# Epoch 00155: val_accuracy did not improve from 0.72532
# Epoch 156/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2593 - auc: 0.9800 - accuracy: 0.8919 - val_loss: 1.2094 - val_auc: 0.8678 - val_accuracy: 0.6628
#
# Epoch 00156: val_accuracy did not improve from 0.72532
# Epoch 157/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2598 - auc: 0.9470 - accuracy: 0.9050 - val_loss: 1.1075 - val_auc: 0.8696 - val_accuracy: 0.6823
#
# Epoch 00157: val_accuracy did not improve from 0.72532
# Epoch 158/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2399 - auc: 0.9784 - accuracy: 0.9042 - val_loss: 1.1604 - val_auc: 0.8721 - val_accuracy: 0.6931
#
# Epoch 00158: val_accuracy did not improve from 0.72532
# Epoch 159/200
# 33/33 [==============================] - 59s 2s/step - loss: 0.2422 - auc: 0.9862 - accuracy: 0.9053 - val_loss: 1.1877 - val_auc: 0.8670 - val_accuracy: 0.6813
#
# Epoch 00159: val_accuracy did not improve from 0.72532
# Epoch 160/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2640 - auc: 0.9830 - accuracy: 0.8958 - val_loss: 1.0405 - val_auc: 0.8802 - val_accuracy: 0.7038
#
# Epoch 00160: val_accuracy did not improve from 0.72532
# Epoch 161/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2597 - auc: 0.9837 - accuracy: 0.8988 - val_loss: 0.9541 - val_auc: 0.8877 - val_accuracy: 0.7028
#
# Epoch 00161: val_accuracy did not improve from 0.72532
# Epoch 162/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2825 - auc: 0.9810 - accuracy: 0.8928 - val_loss: 0.9840 - val_auc: 0.8797 - val_accuracy: 0.7028
#
# Epoch 00162: val_accuracy did not improve from 0.72532
# Epoch 163/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2510 - auc: 0.9770 - accuracy: 0.9049 - val_loss: 1.1112 - val_auc: 0.8817 - val_accuracy: 0.6911
#
# Epoch 00163: val_accuracy did not improve from 0.72532
# Epoch 164/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2722 - auc: 0.9828 - accuracy: 0.8943 - val_loss: 0.9709 - val_auc: 0.8867 - val_accuracy: 0.6950
#
# Epoch 00164: val_accuracy did not improve from 0.72532
# Epoch 165/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2302 - auc: 0.9879 - accuracy: 0.9104 - val_loss: 1.2680 - val_auc: 0.8789 - val_accuracy: 0.6882
#
# Epoch 00165: val_accuracy did not improve from 0.72532
# Epoch 166/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2418 - auc: 0.9787 - accuracy: 0.9059 - val_loss: 0.7721 - val_auc: 0.8976 - val_accuracy: 0.7390
#
# Epoch 00166: val_accuracy improved from 0.72532 to 0.73900, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 167/200
# 33/33 [==============================] - 80s 2s/step - loss: 0.2320 - auc: 0.9876 - accuracy: 0.9090 - val_loss: 1.0974 - val_auc: 0.8803 - val_accuracy: 0.7038
#
# Epoch 00167: val_accuracy did not improve from 0.73900
# Epoch 168/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2466 - auc: 0.9854 - accuracy: 0.9054 - val_loss: 1.0007 - val_auc: 0.8976 - val_accuracy: 0.7234
#
# Epoch 00168: val_accuracy did not improve from 0.73900
# Epoch 169/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2510 - auc: 0.9768 - accuracy: 0.9008 - val_loss: 1.0433 - val_auc: 0.8907 - val_accuracy: 0.7136
#
# Epoch 00169: val_accuracy did not improve from 0.73900
# Epoch 170/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2408 - auc: 0.9792 - accuracy: 0.9108 - val_loss: 1.2585 - val_auc: 0.8808 - val_accuracy: 0.6823
#
# Epoch 00170: val_accuracy did not improve from 0.73900
# Epoch 171/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2575 - auc: 0.9842 - accuracy: 0.9024 - val_loss: 0.8041 - val_auc: 0.8974 - val_accuracy: 0.7498
#
# Epoch 00171: val_accuracy improved from 0.73900 to 0.74976, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 172/200
# 33/33 [==============================] - 77s 2s/step - loss: 0.2455 - auc: 0.9862 - accuracy: 0.9044 - val_loss: 0.9702 - val_auc: 0.8784 - val_accuracy: 0.7155
#
# Epoch 00172: val_accuracy did not improve from 0.74976
# Epoch 173/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2419 - auc: 0.9787 - accuracy: 0.9086 - val_loss: 0.9213 - val_auc: 0.8794 - val_accuracy: 0.7146
#
# Epoch 00173: val_accuracy did not improve from 0.74976
# Epoch 174/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2369 - auc: 0.9864 - accuracy: 0.9048 - val_loss: 0.8827 - val_auc: 0.8859 - val_accuracy: 0.7175
#
# Epoch 00174: val_accuracy did not improve from 0.74976
# Epoch 175/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2342 - auc: 0.9870 - accuracy: 0.9048 - val_loss: 0.9836 - val_auc: 0.8906 - val_accuracy: 0.7126
#
# Epoch 00175: val_accuracy did not improve from 0.74976
# Epoch 176/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2598 - auc: 0.9842 - accuracy: 0.8967 - val_loss: 1.0798 - val_auc: 0.8774 - val_accuracy: 0.6940
#
# Epoch 00176: val_accuracy did not improve from 0.74976
# Epoch 177/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2377 - auc: 0.9786 - accuracy: 0.9115 - val_loss: 0.8583 - val_auc: 0.8860 - val_accuracy: 0.7224
#
# Epoch 00177: val_accuracy did not improve from 0.74976
# Epoch 178/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2340 - auc: 0.9719 - accuracy: 0.9062 - val_loss: 1.1902 - val_auc: 0.8604 - val_accuracy: 0.6843
#
# Epoch 00178: val_accuracy did not improve from 0.74976
# Epoch 179/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2553 - auc: 0.9777 - accuracy: 0.9042 - val_loss: 1.0548 - val_auc: 0.8795 - val_accuracy: 0.6970
#
# Epoch 00179: val_accuracy did not improve from 0.74976
# Epoch 180/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2245 - auc: 0.9883 - accuracy: 0.9100 - val_loss: 0.6927 - val_auc: 0.9058 - val_accuracy: 0.7634
#
# Epoch 00180: val_accuracy improved from 0.74976 to 0.76344, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 181/200
# 33/33 [==============================] - 80s 2s/step - loss: 0.2396 - auc: 0.9868 - accuracy: 0.9072 - val_loss: 1.0313 - val_auc: 0.8937 - val_accuracy: 0.7048
#
# Epoch 00181: val_accuracy did not improve from 0.76344
# Epoch 182/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2106 - auc: 0.9896 - accuracy: 0.9160 - val_loss: 0.9010 - val_auc: 0.8946 - val_accuracy: 0.7273
#
# Epoch 00182: val_accuracy did not improve from 0.76344
# Epoch 183/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2150 - auc: 0.9894 - accuracy: 0.9178 - val_loss: 0.6962 - val_auc: 0.9085 - val_accuracy: 0.7605
#
# Epoch 00183: val_accuracy did not improve from 0.76344
# Epoch 184/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2598 - auc: 0.9841 - accuracy: 0.8996 - val_loss: 0.7680 - val_auc: 0.9086 - val_accuracy: 0.7370
#
# Epoch 00184: val_accuracy did not improve from 0.76344
# Epoch 185/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2219 - auc: 0.9831 - accuracy: 0.9146 - val_loss: 0.9077 - val_auc: 0.8902 - val_accuracy: 0.7195
#
# Epoch 00185: val_accuracy did not improve from 0.76344
# Epoch 186/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2233 - auc: 0.9583 - accuracy: 0.9122 - val_loss: 0.9365 - val_auc: 0.9042 - val_accuracy: 0.7224
#
# Epoch 00186: val_accuracy did not improve from 0.76344
# Epoch 187/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2288 - auc: 0.9875 - accuracy: 0.9126 - val_loss: 0.8820 - val_auc: 0.8892 - val_accuracy: 0.7116
#
# Epoch 00187: val_accuracy did not improve from 0.76344
# Epoch 188/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2267 - auc: 0.9876 - accuracy: 0.9132 - val_loss: 0.9723 - val_auc: 0.8994 - val_accuracy: 0.7136
#
# Epoch 00188: val_accuracy did not improve from 0.76344
# Epoch 189/200
# 33/33 [==============================] - 59s 2s/step - loss: 0.2185 - auc: 0.9810 - accuracy: 0.9139 - val_loss: 0.9154 - val_auc: 0.8981 - val_accuracy: 0.7292
#
# Epoch 00189: val_accuracy did not improve from 0.76344
# Epoch 190/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2250 - auc: 0.9804 - accuracy: 0.9119 - val_loss: 0.8403 - val_auc: 0.9160 - val_accuracy: 0.7341
#
# Epoch 00190: val_accuracy did not improve from 0.76344
# Epoch 191/200
# 33/33 [==============================] - 58s 2s/step - loss: 0.2212 - auc: 0.9886 - accuracy: 0.9142 - val_loss: 0.9220 - val_auc: 0.9031 - val_accuracy: 0.7263
#
# Epoch 00191: val_accuracy did not improve from 0.76344
# Epoch 192/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2259 - auc: 0.9883 - accuracy: 0.9151 - val_loss: 0.8024 - val_auc: 0.9071 - val_accuracy: 0.7380
#
# Epoch 00192: val_accuracy did not improve from 0.76344
# Epoch 193/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2464 - auc: 0.9878 - accuracy: 0.9095 - val_loss: 1.0087 - val_auc: 0.8825 - val_accuracy: 0.7009
#
# Epoch 00193: val_accuracy did not improve from 0.76344
# Epoch 194/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2364 - auc: 0.9795 - accuracy: 0.9087 - val_loss: 1.1314 - val_auc: 0.8888 - val_accuracy: 0.6970
#
# Epoch 00194: val_accuracy did not improve from 0.76344
# Epoch 195/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2162 - auc: 0.9736 - accuracy: 0.9175 - val_loss: 0.9016 - val_auc: 0.9012 - val_accuracy: 0.7292
#
# Epoch 00195: val_accuracy did not improve from 0.76344
# Epoch 196/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2169 - auc: 0.9807 - accuracy: 0.9162 - val_loss: 0.9874 - val_auc: 0.8899 - val_accuracy: 0.7195
#
# Epoch 00196: val_accuracy did not improve from 0.76344
# Epoch 197/200
# 33/33 [==============================] - 57s 2s/step - loss: 0.2245 - auc: 0.9760 - accuracy: 0.9125 - val_loss: 0.7583 - val_auc: 0.9068 - val_accuracy: 0.7615
#
# Epoch 00197: val_accuracy did not improve from 0.76344
# Epoch 198/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.1991 - auc: 0.9902 - accuracy: 0.9194 - val_loss: 0.7067 - val_auc: 0.9111 - val_accuracy: 0.7693
#
# Epoch 00198: val_accuracy improved from 0.76344 to 0.76931, saving model to /content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5
# Epoch 199/200
# 33/33 [==============================] - 77s 2s/step - loss: 0.2643 - auc: 0.9854 - accuracy: 0.9012 - val_loss: 1.1826 - val_auc: 0.8850 - val_accuracy: 0.6706
#
# Epoch 00199: val_accuracy did not improve from 0.76931
# Epoch 200/200
# 33/33 [==============================] - 56s 2s/step - loss: 0.2155 - auc: 0.9854 - accuracy: 0.9108 - val_loss: 0.9186 - val_auc: 0.9070 - val_accuracy: 0.7292
#
# Epoch 00200: val_accuracy did not improve from 0.76931
# --------------------------------------------
#
# Results:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:101: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:110: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:119: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.

# %%
#ad_model_filepath = "/content/drive/My Drive/AD_proj/my_best_models/densenet201_rev1_acc.hdf5"

#
# load model
#
loaded_model = load_model(filepath= ad_model_filepath) 

print("Evaluate on test data")
test_results = loaded_model.evaluate(test_dataset, batch_size=NUM_BATCH_SIZE)
print("test loss, test auc, test acc:", test_results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
test_pred = loaded_model.predict(test_dataset)
test_pred_classes = np.argmax(test_pred, axis=1)

#print ('-----------------------------------------------------')
#print('Confusion Matrix [test DataSet]')
cm = confusion_matrix(test_dataset.classes, test_pred_classes)

print ('-----------------------------------------------------')
print('Classification Report [test DataSet]')
print(classification_report(test_dataset.classes, test_pred_classes, target_names=target_names))

print ('-----------------------------------------------------')
#plot the matrix
f_ad_plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion matrix', cmap=plt.cm.Oranges)
# Out:
# Evaluate on test data
# 10/10 [==============================] - 11s 578ms/step - loss: 1.1377 - auc: 0.8534 - accuracy: 0.7021
# test loss, test auc, test acc: [1.1376540660858154, 0.8534334301948547, 0.702111005783081]
# -----------------------------------------------------
# Classification Report [test DataSet]
#                   precision    recall  f1-score   support
#
#     MildDemented       0.20      0.08      0.12       179
# ModerateDemented       0.00      0.00      0.00        12
#      NonDemented       0.49      0.57      0.53       640
# VeryMildDemented       0.31      0.30      0.31       448
#
#         accuracy                           0.41      1279
#        macro avg       0.25      0.24      0.24      1279
#     weighted avg       0.38      0.41      0.39      1279
#
# -----------------------------------------------------
# Confusion matrix, without normalization
# [[ 15   0 102  62]
#  [  0   0   4   8]
#  [ 34   5 368 233]
#  [ 26   5 281 136]]

# %%
print ('-----------------------------------------------------')
#plot the matrix
f_ad_plot_confusion_matrix(cm, target_names, normalize=True, title='Confusion matrix With Normalization', cmap=plt.cm.Blues)
# Out:
# -----------------------------------------------------
# Normalized confusion matrix
# [[0.08379888 0.         0.5698324  0.34636872]
#  [0.         0.         0.33333333 0.66666667]
#  [0.053125   0.0078125  0.575      0.3640625 ]
#  [0.05803571 0.01116071 0.62723214 0.30357143]]
